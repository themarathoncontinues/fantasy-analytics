# %% [raw]
# workon venv

# %%
import requests

# %%
ENDPOINT = 'https://fantasy.espn.com/apis/v3/games/fba'

# %%
LEAGUE_ID = 69561285
TEAM_ID = 4
SEASON_ID = 2020

# %% [markdown]
# ### Exploring the API

# %%
overview = requests.get(ENDPOINT)

# %%
overview.json()
# Out:
# {'abbrev': 'FBA',
#  'active': True,
#  'currentSeason': {'abbrev': 'FBA 2020',
#   'active': True,
#   'currentScoringPeriod': {'id': 13},
#   'display': True,
#   'displayOrder': 0,
#   'endDate': 1623654000000,
#   'gameId': 3,
#   'id': 2020,
#   'name': 'Fantasy Basketball 2020',
#   'startDate': 1560495600000},
#  'currentSeasonId': 2020,
#  'display': True,
#  'displayOrder': 3,
#  'id': 3,
#  'name': 'Fantasy Basketball',
#  'proSportAbbrev': 'NBA',
#  'proSportName': 'basketball'}

# %%
league = requests.get(f'{ENDPOINT}/leagueHistory/{LEAGUE_ID}')

# %%
league.json()
# Out:
# [{'gameId': 3,
#   'id': 69561285,
#   'members': [{'displayName': 'ESPNFAN9923703121',
#     'id': '{05D164B9-F2F4-4FCA-97CF-1A8C0D02200F}',
#     'isLeagueManager': False},
#    {'displayName': 'mgot13',
#     'id': '{073D2BB1-1612-4E20-8066-303B069EAAFF}',
#     'isLeagueManager': False},
#    {'displayName': 'espn48213793',
#     'id': '{20BEC7B8-923B-4B53-BEC7-B8923B8B534F}',
#     'isLeagueManager': False},
#    {'displayName': 'espn64608829',
#     'id': '{335F7A9A-4E5B-4E2C-B35A-CC9AA019E44C}',
#     'isLeagueManager': False},
#    {'displayName': 'espn42625227',
#     'id': '{36067DE1-1BAD-475C-867D-E11BADF75C48}',
#     'isLeagueManager': False},
#    {'displayName': 'RyanGoydos',
#     'id': '{5AF1DAE9-974E-4B12-864A-A2677B8EB690}',
#     'isLeagueManager': False},
#    {'displayName': 'lsmalley27',
#     'id': '{7065F7B2-E0EC-4EF8-93F7-E3D0D30E5DF4}',
#     'isLeagueManager': False},
#    {'displayName': 'Marc LaMonica',
#     'id': '{8B8AB7FF-3DEE-4932-A8C2-1C104E116C15}',
#     'isLeagueManager': False},
#    {'displayName': 'KOogunwale',
#     'id': '{BFDE2ADA-6AAA-4575-AD6C-4AF34A6B99D5}',
#     'isLeagueManager': False},
#    {'displayName': 'mitchbregs',
#     'id': '{DD012212-1A35-417E-9883-4B1E44BDF89C}',
#     'isLeagueManager': False}],
#   'scoringPeriodId': 177,
#   'seasonId': 2019,
#   'segmentId': 0,
#   'settings': {'name': 'East Gunswick Bears '},
#   'status': {'currentMatchupPeriod': 24,
#    'isActive': True,
#    'latestScoringPeriod': 178},
#   'teams': [{'abbrev': 'MIA',
#     'id': 1,
#     'location': 'Miami ',
#     'nickname': 'Sammy ',
#     'owners': ['{335F7A9A-4E5B-4E2C-B35A-CC9AA019E44C}']},
#    {'abbrev': 'RYAN',
#     'id': 2,
#     'location': 'Mothers Against',
#     'nickname': 'Juuls',
#     'owners': ['{5AF1DAE9-974E-4B12-864A-A2677B8EB690}']},
#    {'abbrev': 'CCh',
#     'id': 3,
#     'location': 'Camden ',
#     'nickname': 'Crack Heads ',
#     'owners': ['{8B8AB7FF-3DEE-4932-A8C2-1C104E116C15}']},
#    {'abbrev': 'RNS',
#     'id': 4,
#     'location': 'New Jersey',
#     'nickname': 'Cumshotters',
#     'owners': ['{DD012212-1A35-417E-9883-4B1E44BDF89C}']},
#    {'abbrev': 'LJB',
#     'id': 5,
#     'location': 'Lejon',
#     'nickname': 'Brames',
#     'owners': ['{073D2BB1-1612-4E20-8066-303B069EAAFF}']},
#    {'abbrev': 'KELL',
#     'id': 6,
#     'location': 'Team',
#     'nickname': 'Kelliher',
#     'owners': ['{20BEC7B8-923B-4B53-BEC7-B8923B8B534F}']},
#    {'abbrev': 'OGUN',
#     'id': 7,
#     'location': 'Flat',
#     'nickname': 'Earthers',
#     'owners': ['{BFDE2ADA-6AAA-4575-AD6C-4AF34A6B99D5}']},
#    {'abbrev': 'SMAL',
#     'id': 8,
#     'location': 'Rock',
#     'nickname': 'Harden',
#     'owners': ['{7065F7B2-E0EC-4EF8-93F7-E3D0D30E5DF4}']},
#    {'abbrev': 'KHU',
#     'id': 9,
#     'location': 'NY',
#     'nickname': 'Knox Her Up',
#     'owners': ['{05D164B9-F2F4-4FCA-97CF-1A8C0D02200F}']},
#    {'abbrev': 'TEMI',
#     'id': 10,
#     'location': 'Team',
#     'nickname': 'Temin',
#     'owners': ['{36067DE1-1BAD-475C-867D-E11BADF75C48}']}]}]

# %%
def authentication(user, pwd):
        url_api_key = 'https://registerdisney.go.com/jgc/v5/client/ESPN-FANTASYLM-PROD/api-key?langPref=en-US'
        url_login = 'https://ha.registerdisney.go.com/jgc/v5/client/ESPN-FANTASYLM-PROD/guest/login?langPref=en-US'

        # Make request to get the API-Key
        headers = {'Content-Type': 'application/json'}
        response = requests.post(url_api_key, headers=headers)
        if response.status_code != 200 or 'api-key' not in response.headers:
            print('Unable to access API-Key')
            print('Retry the authentication or continuing without private league access')
            return
        api_key = response.headers['api-key']

        # Utilize API-Key and login information to get the swid and s2 keys
        headers['authorization'] = 'APIKEY ' + api_key
        payload = {'loginValue': user, 'password': pwd}
        response = requests.post(url_login, headers=headers, json=payload)
        if response.status_code != 200:
            print('Authentication unsuccessful - check username and password input')
            print('Retry the authentication or continuing without private league access')
            return
        data = response.json()
        if data['error'] is not None:
            print('Authentication unsuccessful - error:' + str(data['error']))
            print('Retry the authentication or continuing without private league access')
            return
        return {
            "espn_s2": data['data']['s2'],
            "swid": data['data']['profile']['swid']
        }

# %%
auths = authentication('mitchbregs', 'RutgersBM12!')

# %%
auths
# Out:
# {'espn_s2': 'AEB1W9iGj1b2JWlaGpFOZ7Vk18UL6C9dLLcqh%2BUr356Y4F46%2BKBLcGqvuUMVlI15tNzsTRKzJJ%2Fra0LNZcJbiiq2dbj5vwzlx7EEMC3PLkyv3frgJHCmhQB6RNp6Ou%2F8ZrKNas3tdDPk7rEMypjkWbo6CHRkwKcizsYrh0UBu%2FtpSegS2L6WBqC3i%2F6Zp6hQzU9pLNT5GgeO9IBldIw9%2FQkxm3nlJPWsB0d6RNBNX3VAcjbXVJD%2B1tCvqOb3yleu639tpjGOzlk7XdfiO2AcZa6b',
#  'swid': '{DD012212-1A35-417E-9883-4B1E44BDF89C}'}

# %%
season = requests.get(f'{ENDPOINT}/seasons/{SEASON_ID}/segments/0/leagues/{LEAGUE_ID}', cookies=auths)

# %%
season.json()
# Out:
# {'gameId': 3,
#  'id': 69561285,
#  'members': [{'displayName': 'ESPNFAN9923703121',
#    'id': '{05D164B9-F2F4-4FCA-97CF-1A8C0D02200F}',
#    'isLeagueManager': False},
#   {'displayName': 'mgot13',
#    'id': '{073D2BB1-1612-4E20-8066-303B069EAAFF}',
#    'isLeagueManager': False},
#   {'displayName': 'Eric_winiarski',
#    'id': '{07B59F4A-A159-414C-B59F-4AA159214C3F}',
#    'isLeagueManager': False},
#   {'displayName': 'espn48213793',
#    'id': '{20BEC7B8-923B-4B53-BEC7-B8923B8B534F}',
#    'isLeagueManager': False},
#   {'displayName': 'espn64608829',
#    'id': '{335F7A9A-4E5B-4E2C-B35A-CC9AA019E44C}',
#    'isLeagueManager': False},
#   {'displayName': 'espn42625227',
#    'id': '{36067DE1-1BAD-475C-867D-E11BADF75C48}',
#    'isLeagueManager': False},
#   {'displayName': 'RyanGoydos',
#    'id': '{5AF1DAE9-974E-4B12-864A-A2677B8EB690}',
#    'isLeagueManager': False},
#   {'displayName': 'KOogunwale',
#    'id': '{BFDE2ADA-6AAA-4575-AD6C-4AF34A6B99D5}',
#    'isLeagueManager': False},
#   {'displayName': 'mitchbregs',
#    'id': '{DD012212-1A35-417E-9883-4B1E44BDF89C}',
#    'isLeagueManager': False},
#   {'displayName': 'espn51714985',
#    'id': '{F9FBE5BD-6546-4D97-907D-314EBCA8A0A9}',
#    'isLeagueManager': False}],
#  'scoringPeriodId': 13,
#  'seasonId': 2020,
#  'segmentId': 0,
#  'settings': {'name': 'East Gunswick Bears '},
#  'status': {'currentMatchupPeriod': 2,
#   'isActive': True,
#   'latestScoringPeriod': 13},
#  'teams': [{'abbrev': 'MIA',
#    'id': 1,
#    'location': 'Miami ',
#    'nickname': 'Sammy ',
#    'owners': ['{335F7A9A-4E5B-4E2C-B35A-CC9AA019E44C}']},
#   {'abbrev': 'RYAN',
#    'id': 2,
#    'location': 'Shanghai Organ',
#    'nickname': 'Harvesters',
#    'owners': ['{5AF1DAE9-974E-4B12-864A-A2677B8EB690}']},
#   {'abbrev': '69',
#    'id': 3,
#    'location': 'Brooklyn',
#    'nickname': 'Balls Deep',
#    'owners': ['{07B59F4A-A159-414C-B59F-4AA159214C3F}']},
#   {'abbrev': 'RNS',
#    'id': 4,
#    'location': 'New Jersey',
#    'nickname': 'Cumshotters',
#    'owners': ['{DD012212-1A35-417E-9883-4B1E44BDF89C}']},
#   {'abbrev': 'LJB',
#    'id': 5,
#    'location': 'Lejon',
#    'nickname': 'Brames',
#    'owners': ['{073D2BB1-1612-4E20-8066-303B069EAAFF}']},
#   {'abbrev': 'KELL',
#    'id': 6,
#    'location': 'Team',
#    'nickname': 'Kelliher',
#    'owners': ['{20BEC7B8-923B-4B53-BEC7-B8923B8B534F}']},
#   {'abbrev': 'OGUN',
#    'id': 7,
#    'location': 'Flat',
#    'nickname': 'Earthers',
#    'owners': ['{BFDE2ADA-6AAA-4575-AD6C-4AF34A6B99D5}']},
#   {'abbrev': 'FOOT',
#    'id': 8,
#    'location': 'South Jersey',
#    'nickname': 'Footlongs',
#    'owners': ['{F9FBE5BD-6546-4D97-907D-314EBCA8A0A9}']},
#   {'abbrev': 'KHU',
#    'id': 9,
#    'location': 'NY',
#    'nickname': 'Knox Her Up',
#    'owners': ['{05D164B9-F2F4-4FCA-97CF-1A8C0D02200F}']},
#   {'abbrev': 'TEMI',
#    'id': 10,
#    'location': 'Team',
#    'nickname': 'Temin',
#    'owners': ['{36067DE1-1BAD-475C-867D-E11BADF75C48}']}]}

# %%
params = {
            'view': 'mTeam',
        }

# %%
teams = requests.get(f'{ENDPOINT}/seasons/{SEASON_ID}/segments/0/leagues/{LEAGUE_ID}', cookies=auths, params=params)

# %%
teams.json()
# Out:
# {'draftDetail': {'drafted': True, 'inProgress': False},
#  'gameId': 3,
#  'id': 69561285,
#  'members': [{'displayName': 'ESPNFAN9923703121',
#    'firstName': 'Harold',
#    'id': '{05D164B9-F2F4-4FCA-97CF-1A8C0D02200F}',
#    'lastName': 'Trakhman',
#    'notificationSettings': [{'enabled': True,
#      'id': '55bf5e56-a4a1-4ab5-ae44-4ebf96c6bd94',
#      'type': 'TEAM_TRADE_OFFER'},
#     {'enabled': True,
#      'id': '91084d05-9de7-4ece-810e-4529e46b6814',
#      'type': 'TEAM_PLAYER_NEWS'},
#     {'enabled': True,
#      'id': '3ab22854-11ee-4dfb-aeba-0ef8122a9ea3',
#      'type': 'TEAM_PLAYER_AVAILABILITY'},
#     {'enabled': True,
#      'id': '24a5662d-2a95-4423-bcc4-1c64281feae1',
#      'type': 'DRAFT'}]},
#   {'displayName': 'mgot13',
#    'firstName': 'Matt',
#    'id': '{073D2BB1-1612-4E20-8066-303B069EAAFF}',
#    'lastName': 'Gotkin',
#    'notificationSettings': [{'enabled': True,
#      'id': '26c3d563-7d2b-453d-ba16-639eb73b252f',
#      'type': 'TEAM_PLAYER_NEWS'},
#     {'enabled': True,
#      'id': '61b1e2e7-44fe-4a96-acff-2983a3db8f05',
#      'type': 'TEAM_TRADE_OFFER'},
#     {'enabled': True,
#      'id': '0ac95c71-e3b1-4d12-be9d-51297530754d',
#      'type': 'TEAM_PLAYER_AVAILABILITY'},
#     {'enabled': True,
#      'id': 'd03cb4d8-499a-4a5e-bbc0-a371c73fb839',
#      'type': 'DRAFT'}]},
#   {'displayName': 'Eric_winiarski',
#    'firstName': 'Eric',
#    'id': '{07B59F4A-A159-414C-B59F-4AA159214C3F}',
#    'lastName': 'Winiarski',
#    'notificationSettings': [{'enabled': True,
#      'id': '59686d9e-1f50-4d6b-b7ea-4b084738c80b',
#      'type': 'TEAM_TRADE_OFFER'},
#     {'enabled': True,
#      'id': '76cc8e3b-e9f0-4740-b53e-91238e58255b',
#      'type': 'TEAM_PLAYER_NEWS'},
#     {'enabled': True,
#      'id': 'c8d72949-8158-471b-a218-afae9d60a517',
#      'type': 'DRAFT'},
#     {'enabled': True,
#      'id': 'e3f931cc-e9f6-4d48-81a3-e8dd313bb25e',
#      'type': 'TEAM_PLAYER_AVAILABILITY'}]},
#   {'displayName': 'espn48213793',
#    'firstName': 'Kyle',
#    'id': '{20BEC7B8-923B-4B53-BEC7-B8923B8B534F}',
#    'lastName': 'Kelliher',
#    'notificationSettings': [{'enabled': True,
#      'id': '5a81da7a-2483-4d8e-90eb-d62d2964c87d',
#      'type': 'DRAFT'},
#     {'enabled': True,
#      'id': '458aab0c-0fce-4cb8-abc1-c3b248f939e9',
#      'type': 'TEAM_PLAYER_NEWS'},
#     {'enabled': True,
#      'id': '2a17470f-f1d5-4462-bfe0-bfca12c53b00',
#      'type': 'TEAM_PLAYER_AVAILABILITY'},
#     {'enabled': True,
#      'id': 'c4f1198f-c4ad-4b84-8093-4ac7656bd4af',
#      'type': 'TEAM_TRADE_OFFER'}]},
#   {'displayName': 'espn64608829',
#    'firstName': 'Sam',
#    'id': '{335F7A9A-4E5B-4E2C-B35A-CC9AA019E44C}',
#    'lastName': 'Markovich',
#    'notificationSettings': [{'enabled': True,
#      'id': '455db1b4-2f06-46b4-b60a-468c105bc255',
#      'type': 'TEAM_PLAYER_NEWS'},
#     {'enabled': True,
#      'id': 'b13186d9-6c9b-4cbe-9e7f-7e1f8e12b885',
#      'type': 'TEAM_TRADE_OFFER'},
#     {'enabled': True,
#      'id': '9808ff85-a18b-4888-8bb8-a4935c8d3bc5',
#      'type': 'TEAM_PLAYER_AVAILABILITY'},
#     {'enabled': True,
#      'id': '6b4668a8-09d0-4c42-8c1a-1fa6146526a1',
#      'type': 'DRAFT'}]},
#   {'displayName': 'espn42625227',
#    'firstName': 'Bryan',
#    'id': '{36067DE1-1BAD-475C-867D-E11BADF75C48}',
#    'lastName': 'Temin',
#    'notificationSettings': [{'enabled': True,
#      'id': '2403c2c0-2aa4-45c8-a827-2102c328651e',
#      'type': 'TEAM_PLAYER_NEWS'},
#     {'enabled': True,
#      'id': 'faf74358-232c-4ab3-83dd-4323bbacb01c',
#      'type': 'TEAM_PLAYER_AVAILABILITY'},
#     {'enabled': True,
#      'id': 'f9295a62-5f8d-404e-95db-d1fdf9173e99',
#      'type': 'TEAM_TRADE_OFFER'},
#     {'enabled': True,
#      'id': '75bcfdf2-16fe-4a6f-87c1-f4961b6bd775',
#      'type': 'DRAFT'}]},
#   {'displayName': 'RyanGoydos',
#    'firstName': 'Ryan',
#    'id': '{5AF1DAE9-974E-4B12-864A-A2677B8EB690}',
#    'lastName': 'Goydos',
#    'notificationSettings': [{'enabled': True,
#      'id': '2e6eda68-6b76-470f-a11d-e6317882b7f1',
#      'type': 'TEAM_PLAYER_NEWS'},
#     {'enabled': True,
#      'id': '63e682e7-9bd4-495d-9b7e-9c1a57a632c1',
#      'type': 'TEAM_PLAYER_AVAILABILITY'},
#     {'enabled': True,
#      'id': 'd717c7ea-b5ce-4f8f-bd8c-e6f8df177b44',
#      'type': 'TEAM_TRADE_OFFER'},
#     {'enabled': True,
#      'id': '728e601f-a0fd-418f-a884-2c126fd0f007',
#      'type': 'DRAFT'}]},
#   {'displayName': 'KOogunwale',
#    'firstName': 'Kayo ',
#    'id': '{BFDE2ADA-6AAA-4575-AD6C-4AF34A6B99D5}',
#    'lastName': 'Ogunwale',
#    'notificationSettings': [{'enabled': True,
#      'id': '61ef3f4d-c822-4681-8131-a8a907087da4',
#      'type': 'TEAM_PLAYER_AVAILABILITY'},
#     {'enabled': True,
#      'id': '73b0f8db-4117-481a-af6f-124948e99818',
#      'type': 'TEAM_PLAYER_NEWS'},
#     {'enabled': True,
#      'id': 'a8ab7d8e-472c-43c0-aa9b-9f04c84fab2c',
#      'type': 'DRAFT'},
#     {'enabled': True,
#      'id': 'fe733a13-ed8c-4113-b153-91b32e5c3679',
#      'type': 'TEAM_TRADE_OFFER'}]},
#   {'displayName': 'mitchbregs',
#    'firstName': 'Mitchell',
#    'id': '{DD012212-1A35-417E-9883-4B1E44BDF89C}',
#    'lastName': 'Bregman',
#    'notificationSettings': [{'enabled': True,
#      'id': 'cd5e6b87-577f-425a-b37e-bb1b747e89f8',
#      'type': 'TEAM_PLAYER_AVAILABILITY'},
#     {'enabled': True,
#      'id': '961d1302-04be-4e36-9271-fe3a502b6956',
#      'type': 'DRAFT'},
#     {'enabled': True,
#      'id': '9865b32a-9872-49d6-bb0c-b368d413e838',
#      'type': 'TEAM_TRADE_OFFER'},
#     {'enabled': True,
#      'id': '9dd2ec49-8841-4eb1-9f50-75a6b57f61ff',
#      'type': 'TEAM_PLAYER_NEWS'}]},
#   {'displayName': 'espn51714985',
#    'firstName': 'pascal',
#    'id': '{F9FBE5BD-6546-4D97-907D-314EBCA8A0A9}',
#    'lastName': 'dylewicz',
#    'notificationSettings': [{'enabled': True,
#      'id': '9c47375b-d8a6-43be-8d04-02e0f57142f5',
#      'type': 'DRAFT'},
#     {'enabled': True,
#      'id': '32b84e4e-3093-46db-8bd8-c0fe53fb1401',
#      'type': 'TEAM_TRADE_OFFER'},
#     {'enabled': True,
#      'id': '26936691-37f1-41d8-8245-3d055a211a8b',
#      'type': 'TEAM_PLAYER_AVAILABILITY'},
#     {'enabled': True,
#      'id': '8c07665f-77bc-4976-b991-304f1a62edd7',
#      'type': 'TEAM_PLAYER_NEWS'}]}],
#  'scoringPeriodId': 13,
#  'seasonId': 2020,
#  'segmentId': 0,
#  'status': {'activatedDate': 1570636666717,
#   'createdAsLeagueType': 4,
#   'currentLeagueType': 0,
#   'currentMatchupPeriod': 2,
#   'finalScoringPeriod': 177,
#   'firstScoringPeriod': 1,
#   'isActive': True,
#   'isExpired': False,
#   'isFull': True,
#   'isPlayoffMatchupEdited': False,
#   'isToBeDeleted': False,
#   'isViewable': False,
#   'isWaiverOrderEdited': False,
#   'latestScoringPeriod': 13,
#   'previousSeasons': [2019],
#   'standingsUpdateDate': 1572771488081,
#   'teamsJoined': 10,
#   'transactionScoringPeriod': 13,
#   'waiverLastExecutionDate': 1572771488068,
#   'waiverProcessStatus': {'2019-10-23T08:07:44.270+0000': 2,
#    '2019-10-25T08:00:20.236+0000': 1,
#    '2019-10-31T08:37:15.295+0000': 1,
#    '2019-11-03T08:58:08.068+0000': 1}},
#  'teams': [{'abbrev': 'MIA',
#    'currentProjectedRank': 0,
#    'divisionId': 0,
#    'draftDayProjectedRank': 0,
#    'id': 1,
#    'isActive': False,
#    'location': 'Miami ',
#    'logo': 'https://images1.miaminewtimes.com/imager/is-ricky-rozay-the-phattest-rapper-of-all/u/original/6435977/rickross_five_phattest_rappers_ever.jpg',
#    'logoType': 'CUSTOM_VALID',
#    'nickname': 'Sammy ',
#    'owners': ['{335F7A9A-4E5B-4E2C-B35A-CC9AA019E44C}'],
#    'playoffSeed': 4,
#    'points': 0.0,
#    'pointsAdjusted': 0.0,
#    'pointsDelta': 0.0,
#    'primaryOwner': '{335F7A9A-4E5B-4E2C-B35A-CC9AA019E44C}',
#    'rankCalculatedFinal': 0,
#    'rankFinal': 0,
#    'record': {'away': {'gamesBack': 0.0,
#      'losses': 0,
#      'percentage': 0.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 0,
#      'streakType': 'NONE',
#      'ties': 0,
#      'wins': 0},
#     'division': {'gamesBack': 0.0,
#      'losses': 0,
#      'percentage': 1.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 1,
#      'streakType': 'WIN',
#      'ties': 0,
#      'wins': 1},
#     'home': {'gamesBack': 0.0,
#      'losses': 0,
#      'percentage': 1.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 1,
#      'streakType': 'WIN',
#      'ties': 0,
#      'wins': 1},
#     'overall': {'gamesBack': 0.0,
#      'losses': 0,
#      'percentage': 1.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 1,
#      'streakType': 'WIN',
#      'ties': 0,
#      'wins': 1}},
#    'tradeBlock': {},
#    'transactionCounter': {'acquisitionBudgetSpent': 0,
#     'acquisitions': 6,
#     'drops': 6,
#     'matchupAcquisitionTotals': {'1': 3, '2': 3},
#     'misc': 0,
#     'moveToActive': 66,
#     'moveToIR': 0,
#     'paid': 0.0,
#     'teamCharges': 0.0,
#     'trades': 0},
#    'valuesByStat': {'0': 1304.0,
#     '1': 61.0,
#     '2': 81.0,
#     '3': 266.0,
#     '37': 11.0,
#     '6': 512.0,
#     '38': 0.0,
#     '7': 1.0,
#     '8': 0.0,
#     '10': 4.0,
#     '11': 171.0,
#     '12': 1.0,
#     '13': 456.0,
#     '14': 1043.0,
#     '15': 254.0,
#     '17': 138.0,
#     '19': 0.43720038},
#    'waiverRank': 5},
#   {'abbrev': 'RYAN',
#    'currentProjectedRank': 0,
#    'divisionId': 1,
#    'draftDayProjectedRank': 0,
#    'id': 2,
#    'isActive': False,
#    'location': 'Shanghai Organ',
#    'logo': 'https://g.espncdn.com/lm-static/logo-packs/core/SimpleShields/shields-1.svg',
#    'logoType': 'VECTOR',
#    'nickname': 'Harvesters',
#    'owners': ['{5AF1DAE9-974E-4B12-864A-A2677B8EB690}'],
#    'playoffSeed': 3,
#    'points': 0.0,
#    'pointsAdjusted': 0.0,
#    'pointsDelta': 0.0,
#    'primaryOwner': '{5AF1DAE9-974E-4B12-864A-A2677B8EB690}',
#    'rankCalculatedFinal': 0,
#    'rankFinal': 0,
#    'record': {'away': {'gamesBack': 0.0,
#      'losses': 0,
#      'percentage': 1.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 1,
#      'streakType': 'WIN',
#      'ties': 0,
#      'wins': 1},
#     'division': {'gamesBack': 0.0,
#      'losses': 0,
#      'percentage': 1.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 1,
#      'streakType': 'WIN',
#      'ties': 0,
#      'wins': 1},
#     'home': {'gamesBack': 0.0,
#      'losses': 0,
#      'percentage': 0.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 0,
#      'streakType': 'NONE',
#      'ties': 0,
#      'wins': 0},
#     'overall': {'gamesBack': 0.0,
#      'losses': 0,
#      'percentage': 1.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 1,
#      'streakType': 'WIN',
#      'ties': 0,
#      'wins': 1}},
#    'tradeBlock': {},
#    'transactionCounter': {'acquisitionBudgetSpent': 0,
#     'acquisitions': 2,
#     'drops': 2,
#     'matchupAcquisitionTotals': {'1': 2},
#     'misc': 0,
#     'moveToActive': 61,
#     'moveToIR': 0,
#     'paid': 0.0,
#     'teamCharges': 0.0,
#     'trades': 0},
#    'valuesByStat': {'0': 1189.0,
#     '1': 52.0,
#     '2': 84.0,
#     '3': 294.0,
#     '37': 14.0,
#     '6': 485.0,
#     '38': 1.0,
#     '7': 0.0,
#     '8': 0.0,
#     '10': 4.0,
#     '11': 173.0,
#     '12': 1.0,
#     '13': 402.0,
#     '14': 930.0,
#     '15': 263.0,
#     '17': 122.0,
#     '19': 0.43225806},
#    'waiverRank': 6},
#   {'abbrev': '69',
#    'currentProjectedRank': 0,
#    'divisionId': 0,
#    'draftDayProjectedRank': 0,
#    'id': 3,
#    'isActive': False,
#    'location': 'Brooklyn',
#    'logo': 'https://g.espncdn.com/lm-static/logo-packs/core/StadiumFoods-ESPN/stadium-foods_hot-dog.svg',
#    'logoType': 'VECTOR',
#    'nickname': 'Balls Deep',
#    'owners': ['{07B59F4A-A159-414C-B59F-4AA159214C3F}'],
#    'playoffSeed': 2,
#    'points': 0.0,
#    'pointsAdjusted': 0.0,
#    'pointsDelta': 0.0,
#    'primaryOwner': '{07B59F4A-A159-414C-B59F-4AA159214C3F}',
#    'rankCalculatedFinal': 0,
#    'rankFinal': 0,
#    'record': {'away': {'gamesBack': 0.0,
#      'losses': 0,
#      'percentage': 0.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 0,
#      'streakType': 'NONE',
#      'ties': 0,
#      'wins': 0},
#     'division': {'gamesBack': 0.0,
#      'losses': 0,
#      'percentage': 1.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 1,
#      'streakType': 'WIN',
#      'ties': 0,
#      'wins': 1},
#     'home': {'gamesBack': 0.0,
#      'losses': 0,
#      'percentage': 1.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 1,
#      'streakType': 'WIN',
#      'ties': 0,
#      'wins': 1},
#     'overall': {'gamesBack': 0.0,
#      'losses': 0,
#      'percentage': 1.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 1,
#      'streakType': 'WIN',
#      'ties': 0,
#      'wins': 1}},
#    'tradeBlock': {},
#    'transactionCounter': {'acquisitionBudgetSpent': 0,
#     'acquisitions': 0,
#     'drops': 0,
#     'matchupAcquisitionTotals': {},
#     'misc': 0,
#     'moveToActive': 44,
#     'moveToIR': 0,
#     'paid': 0.0,
#     'teamCharges': 0.0,
#     'trades': 0},
#    'valuesByStat': {'0': 1262.0,
#     '1': 35.0,
#     '2': 73.0,
#     '3': 239.0,
#     '37': 12.0,
#     '6': 414.0,
#     '38': 1.0,
#     '7': 1.0,
#     '8': 2.0,
#     '10': 3.0,
#     '11': 163.0,
#     '12': 2.0,
#     '13': 459.0,
#     '14': 982.0,
#     '15': 194.0,
#     '17': 150.0,
#     '19': 0.46741344},
#    'waiverRank': 3},
#   {'abbrev': 'RNS',
#    'currentProjectedRank': 0,
#    'divisionId': 1,
#    'draftDayProjectedRank': 0,
#    'draftStrategy': {'futureKeeperPlayerIds': [], 'keeperPlayerIds': []},
#    'id': 4,
#    'isActive': False,
#    'location': 'New Jersey',
#    'logo': 'https://g.espncdn.com/lm-static/logo-packs/core/Solo/ESPN_Star_Wars_Chebacca-01.svg',
#    'logoType': 'VECTOR',
#    'nickname': 'Cumshotters',
#    'owners': ['{DD012212-1A35-417E-9883-4B1E44BDF89C}'],
#    'playoffSeed': 1,
#    'points': 0.0,
#    'pointsAdjusted': 0.0,
#    'pointsDelta': 0.0,
#    'primaryOwner': '{DD012212-1A35-417E-9883-4B1E44BDF89C}',
#    'rankCalculatedFinal': 0,
#    'rankFinal': 0,
#    'record': {'away': {'gamesBack': 0.0,
#      'losses': 0,
#      'percentage': 1.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 1,
#      'streakType': 'WIN',
#      'ties': 0,
#      'wins': 1},
#     'division': {'gamesBack': 0.0,
#      'losses': 0,
#      'percentage': 1.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 1,
#      'streakType': 'WIN',
#      'ties': 0,
#      'wins': 1},
#     'home': {'gamesBack': 0.0,
#      'losses': 0,
#      'percentage': 0.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 0,
#      'streakType': 'NONE',
#      'ties': 0,
#      'wins': 0},
#     'overall': {'gamesBack': 0.0,
#      'losses': 0,
#      'percentage': 1.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 1,
#      'streakType': 'WIN',
#      'ties': 0,
#      'wins': 1}},
#    'tradeBlock': {},
#    'transactionCounter': {'acquisitionBudgetSpent': 0,
#     'acquisitions': 1,
#     'drops': 1,
#     'matchupAcquisitionTotals': {'2': 1},
#     'misc': 0,
#     'moveToActive': 55,
#     'moveToIR': 0,
#     'paid': 0.0,
#     'teamCharges': 0.0,
#     'trades': 0},
#    'valuesByStat': {'0': 1106.0,
#     '1': 47.0,
#     '2': 81.0,
#     '3': 220.0,
#     '37': 10.0,
#     '6': 453.0,
#     '38': 0.0,
#     '7': 0.0,
#     '8': 1.0,
#     '10': 0.0,
#     '11': 156.0,
#     '12': 2.0,
#     '13': 411.0,
#     '14': 897.0,
#     '15': 206.0,
#     '17': 78.0,
#     '19': 0.45819398},
#    'waiverRank': 2},
#   {'abbrev': 'LJB',
#    'currentProjectedRank': 0,
#    'divisionId': 0,
#    'draftDayProjectedRank': 0,
#    'id': 5,
#    'isActive': False,
#    'location': 'Lejon',
#    'logo': 'https://pbs.twimg.com/media/DU-0L3IWkAEGQb0.jpg:large',
#    'logoType': 'CUSTOM_VALID',
#    'nickname': 'Brames',
#    'owners': ['{073D2BB1-1612-4E20-8066-303B069EAAFF}'],
#    'playoffSeed': 10,
#    'points': 0.0,
#    'pointsAdjusted': 0.0,
#    'pointsDelta': 0.0,
#    'primaryOwner': '{073D2BB1-1612-4E20-8066-303B069EAAFF}',
#    'rankCalculatedFinal': 0,
#    'rankFinal': 0,
#    'record': {'away': {'gamesBack': 0.0,
#      'losses': 1,
#      'percentage': 0.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 1,
#      'streakType': 'LOSS',
#      'ties': 0,
#      'wins': 0},
#     'division': {'gamesBack': 1.0,
#      'losses': 1,
#      'percentage': 0.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 1,
#      'streakType': 'LOSS',
#      'ties': 0,
#      'wins': 0},
#     'home': {'gamesBack': 0.0,
#      'losses': 0,
#      'percentage': 0.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 0,
#      'streakType': 'NONE',
#      'ties': 0,
#      'wins': 0},
#     'overall': {'gamesBack': 1.0,
#      'losses': 1,
#      'percentage': 0.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 1,
#      'streakType': 'LOSS',
#      'ties': 0,
#      'wins': 0}},
#    'tradeBlock': {},
#    'transactionCounter': {'acquisitionBudgetSpent': 0,
#     'acquisitions': 2,
#     'drops': 2,
#     'matchupAcquisitionTotals': {'2': 2},
#     'misc': 0,
#     'moveToActive': 41,
#     'moveToIR': 0,
#     'paid': 0.0,
#     'teamCharges': 0.0,
#     'trades': 0},
#    'valuesByStat': {'0': 1274.0,
#     '1': 59.0,
#     '2': 75.0,
#     '3': 272.0,
#     '37': 20.0,
#     '6': 586.0,
#     '38': 1.0,
#     '7': 0.0,
#     '8': 0.0,
#     '10': 6.0,
#     '11': 184.0,
#     '12': 4.0,
#     '13': 472.0,
#     '14': 979.0,
#     '15': 210.0,
#     '17': 120.0,
#     '19': 0.48212462},
#    'waiverRank': 9},
#   {'abbrev': 'KELL',
#    'currentProjectedRank': 0,
#    'divisionId': 1,
#    'draftDayProjectedRank': 0,
#    'id': 6,
#    'isActive': False,
#    'location': 'Team',
#    'logo': 'https://g.espncdn.com/lm-static/fba/images/default_logos/15.svg',
#    'logoType': 'VECTOR',
#    'nickname': 'Kelliher',
#    'owners': ['{20BEC7B8-923B-4B53-BEC7-B8923B8B534F}'],
#    'playoffSeed': 9,
#    'points': 0.0,
#    'pointsAdjusted': 0.0,
#    'pointsDelta': 0.0,
#    'primaryOwner': '{20BEC7B8-923B-4B53-BEC7-B8923B8B534F}',
#    'rankCalculatedFinal': 0,
#    'rankFinal': 0,
#    'record': {'away': {'gamesBack': 0.0,
#      'losses': 1,
#      'percentage': 0.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 1,
#      'streakType': 'LOSS',
#      'ties': 0,
#      'wins': 0},
#     'division': {'gamesBack': 0.5,
#      'losses': 0,
#      'percentage': 0.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 0,
#      'streakType': 'NONE',
#      'ties': 0,
#      'wins': 0},
#     'home': {'gamesBack': 0.0,
#      'losses': 0,
#      'percentage': 0.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 0,
#      'streakType': 'NONE',
#      'ties': 0,
#      'wins': 0},
#     'overall': {'gamesBack': 1.0,
#      'losses': 1,
#      'percentage': 0.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 1,
#      'streakType': 'LOSS',
#      'ties': 0,
#      'wins': 0}},
#    'tradeBlock': {},
#    'transactionCounter': {'acquisitionBudgetSpent': 0,
#     'acquisitions': 10,
#     'drops': 10,
#     'matchupAcquisitionTotals': {'1': 4, '2': 6},
#     'misc': 0,
#     'moveToActive': 27,
#     'moveToIR': 0,
#     'paid': 0.0,
#     'teamCharges': 0.0,
#     'trades': 0},
#    'valuesByStat': {'0': 960.0,
#     '1': 39.0,
#     '2': 69.0,
#     '3': 237.0,
#     '37': 17.0,
#     '6': 375.0,
#     '38': 1.0,
#     '7': 0.0,
#     '8': 0.0,
#     '10': 3.0,
#     '11': 159.0,
#     '12': 0.0,
#     '13': 350.0,
#     '14': 739.0,
#     '15': 199.0,
#     '17': 61.0,
#     '19': 0.47361299},
#    'waiverRank': 7},
#   {'abbrev': 'OGUN',
#    'currentProjectedRank': 0,
#    'divisionId': 0,
#    'draftDayProjectedRank': 0,
#    'id': 7,
#    'isActive': False,
#    'location': 'Flat',
#    'logo': 'https://g.espncdn.com/lm-static/fba/images/default_logos/2.svg',
#    'logoType': 'VECTOR',
#    'nickname': 'Earthers',
#    'owners': ['{BFDE2ADA-6AAA-4575-AD6C-4AF34A6B99D5}'],
#    'playoffSeed': 5,
#    'points': 0.0,
#    'pointsAdjusted': 0.0,
#    'pointsDelta': 0.0,
#    'primaryOwner': '{BFDE2ADA-6AAA-4575-AD6C-4AF34A6B99D5}',
#    'rankCalculatedFinal': 0,
#    'rankFinal': 0,
#    'record': {'away': {'gamesBack': 0.0,
#      'losses': 0,
#      'percentage': 0.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 0,
#      'streakType': 'NONE',
#      'ties': 0,
#      'wins': 0},
#     'division': {'gamesBack': 0.5,
#      'losses': 0,
#      'percentage': 0.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 0,
#      'streakType': 'NONE',
#      'ties': 0,
#      'wins': 0},
#     'home': {'gamesBack': 0.0,
#      'losses': 0,
#      'percentage': 1.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 1,
#      'streakType': 'WIN',
#      'ties': 0,
#      'wins': 1},
#     'overall': {'gamesBack': 0.0,
#      'losses': 0,
#      'percentage': 1.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 1,
#      'streakType': 'WIN',
#      'ties': 0,
#      'wins': 1}},
#    'tradeBlock': {},
#    'transactionCounter': {'acquisitionBudgetSpent': 0,
#     'acquisitions': 2,
#     'drops': 2,
#     'matchupAcquisitionTotals': {'1': 2},
#     'misc': 0,
#     'moveToActive': 37,
#     'moveToIR': 0,
#     'paid': 0.0,
#     'teamCharges': 0.0,
#     'trades': 0},
#    'valuesByStat': {'0': 1074.0,
#     '1': 45.0,
#     '2': 66.0,
#     '3': 213.0,
#     '37': 11.0,
#     '6': 406.0,
#     '38': 2.0,
#     '7': 0.0,
#     '8': 0.0,
#     '10': 4.0,
#     '11': 145.0,
#     '12': 3.0,
#     '13': 395.0,
#     '14': 807.0,
#     '15': 200.0,
#     '17': 84.0,
#     '19': 0.48946716},
#    'waiverRank': 8},
#   {'abbrev': 'FOOT',
#    'currentProjectedRank': 0,
#    'divisionId': 1,
#    'draftDayProjectedRank': 0,
#    'id': 8,
#    'isActive': False,
#    'location': 'South Jersey',
#    'logo': 'https://g.espncdn.com/lm-static/logo-packs/core/StadiumFoods-ESPN/stadium-foods_hot-dog.svg',
#    'logoType': 'VECTOR',
#    'nickname': 'Footlongs',
#    'owners': ['{F9FBE5BD-6546-4D97-907D-314EBCA8A0A9}'],
#    'playoffSeed': 8,
#    'points': 0.0,
#    'pointsAdjusted': 0.0,
#    'pointsDelta': 0.0,
#    'primaryOwner': '{F9FBE5BD-6546-4D97-907D-314EBCA8A0A9}',
#    'rankCalculatedFinal': 0,
#    'rankFinal': 0,
#    'record': {'away': {'gamesBack': 0.0,
#      'losses': 0,
#      'percentage': 0.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 0,
#      'streakType': 'NONE',
#      'ties': 0,
#      'wins': 0},
#     'division': {'gamesBack': 1.0,
#      'losses': 1,
#      'percentage': 0.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 1,
#      'streakType': 'LOSS',
#      'ties': 0,
#      'wins': 0},
#     'home': {'gamesBack': 0.0,
#      'losses': 1,
#      'percentage': 0.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 1,
#      'streakType': 'LOSS',
#      'ties': 0,
#      'wins': 0},
#     'overall': {'gamesBack': 1.0,
#      'losses': 1,
#      'percentage': 0.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 1,
#      'streakType': 'LOSS',
#      'ties': 0,
#      'wins': 0}},
#    'tradeBlock': {},
#    'transactionCounter': {'acquisitionBudgetSpent': 0,
#     'acquisitions': 2,
#     'drops': 2,
#     'matchupAcquisitionTotals': {'1': 2},
#     'misc': 0,
#     'moveToActive': 46,
#     'moveToIR': 0,
#     'paid': 0.0,
#     'teamCharges': 0.0,
#     'trades': 0},
#    'valuesByStat': {'0': 1102.0,
#     '1': 41.0,
#     '2': 60.0,
#     '3': 251.0,
#     '37': 13.0,
#     '6': 403.0,
#     '38': 0.0,
#     '7': 1.0,
#     '8': 1.0,
#     '10': 4.0,
#     '11': 179.0,
#     '12': 1.0,
#     '13': 401.0,
#     '14': 945.0,
#     '15': 198.0,
#     '17': 102.0,
#     '19': 0.42433862},
#    'waiverRank': 1},
#   {'abbrev': 'KHU',
#    'currentProjectedRank': 0,
#    'divisionId': 0,
#    'draftDayProjectedRank': 0,
#    'id': 9,
#    'isActive': False,
#    'location': 'NY',
#    'logo': 'https://g.espncdn.com/lm-static/logo-packs/core/StarsAndFlames/stars_flames-8.svg',
#    'logoType': 'VECTOR',
#    'nickname': 'Knox Her Up',
#    'owners': ['{05D164B9-F2F4-4FCA-97CF-1A8C0D02200F}'],
#    'playoffSeed': 7,
#    'points': 0.0,
#    'pointsAdjusted': 0.0,
#    'pointsDelta': 0.0,
#    'primaryOwner': '{05D164B9-F2F4-4FCA-97CF-1A8C0D02200F}',
#    'rankCalculatedFinal': 0,
#    'rankFinal': 0,
#    'record': {'away': {'gamesBack': 0.0,
#      'losses': 1,
#      'percentage': 0.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 1,
#      'streakType': 'LOSS',
#      'ties': 0,
#      'wins': 0},
#     'division': {'gamesBack': 1.0,
#      'losses': 1,
#      'percentage': 0.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 1,
#      'streakType': 'LOSS',
#      'ties': 0,
#      'wins': 0},
#     'home': {'gamesBack': 0.0,
#      'losses': 0,
#      'percentage': 0.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 0,
#      'streakType': 'NONE',
#      'ties': 0,
#      'wins': 0},
#     'overall': {'gamesBack': 1.0,
#      'losses': 1,
#      'percentage': 0.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 1,
#      'streakType': 'LOSS',
#      'ties': 0,
#      'wins': 0}},
#    'tradeBlock': {},
#    'transactionCounter': {'acquisitionBudgetSpent': 0,
#     'acquisitions': 7,
#     'drops': 7,
#     'matchupAcquisitionTotals': {'1': 4, '2': 3},
#     'misc': 0,
#     'moveToActive': 43,
#     'moveToIR': 0,
#     'paid': 0.0,
#     'teamCharges': 0.0,
#     'trades': 0},
#    'valuesByStat': {'0': 1188.0,
#     '1': 39.0,
#     '2': 62.0,
#     '3': 211.0,
#     '37': 10.0,
#     '6': 364.0,
#     '38': 0.0,
#     '7': 1.0,
#     '8': 0.0,
#     '10': 7.0,
#     '11': 142.0,
#     '12': 0.0,
#     '13': 421.0,
#     '14': 957.0,
#     '15': 206.0,
#     '17': 140.0,
#     '19': 0.43991641},
#    'waiverRank': 10},
#   {'abbrev': 'TEMI',
#    'currentProjectedRank': 0,
#    'divisionId': 1,
#    'draftDayProjectedRank': 0,
#    'id': 10,
#    'isActive': False,
#    'location': 'Team',
#    'logo': 'https://g.espncdn.com/lm-static/fba/images/default_logos/19.svg',
#    'logoType': 'VECTOR',
#    'nickname': 'Temin',
#    'owners': ['{36067DE1-1BAD-475C-867D-E11BADF75C48}'],
#    'playoffSeed': 6,
#    'points': 0.0,
#    'pointsAdjusted': 0.0,
#    'pointsDelta': 0.0,
#    'primaryOwner': '{36067DE1-1BAD-475C-867D-E11BADF75C48}',
#    'rankCalculatedFinal': 0,
#    'rankFinal': 0,
#    'record': {'away': {'gamesBack': 0.0,
#      'losses': 0,
#      'percentage': 0.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 0,
#      'streakType': 'NONE',
#      'ties': 0,
#      'wins': 0},
#     'division': {'gamesBack': 1.0,
#      'losses': 1,
#      'percentage': 0.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 1,
#      'streakType': 'LOSS',
#      'ties': 0,
#      'wins': 0},
#     'home': {'gamesBack': 0.0,
#      'losses': 1,
#      'percentage': 0.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 1,
#      'streakType': 'LOSS',
#      'ties': 0,
#      'wins': 0},
#     'overall': {'gamesBack': 1.0,
#      'losses': 1,
#      'percentage': 0.0,
#      'pointsAgainst': 0.0,
#      'pointsFor': 0.0,
#      'streakLength': 1,
#      'streakType': 'LOSS',
#      'ties': 0,
#      'wins': 0}},
#    'tradeBlock': {},
#    'transactionCounter': {'acquisitionBudgetSpent': 0,
#     'acquisitions': 0,
#     'drops': 0,
#     'matchupAcquisitionTotals': {},
#     'misc': 0,
#     'moveToActive': 23,
#     'moveToIR': 0,
#     'paid': 0.0,
#     'teamCharges': 0.0,
#     'trades': 0},
#    'valuesByStat': {'0': 998.0,
#     '1': 33.0,
#     '2': 57.0,
#     '3': 257.0,
#     '37': 11.0,
#     '6': 398.0,
#     '38': 4.0,
#     '7': 0.0,
#     '8': 1.0,
#     '10': 4.0,
#     '11': 154.0,
#     '12': 0.0,
#     '13': 357.0,
#     '14': 775.0,
#     '15': 193.0,
#     '17': 91.0,
#     '19': 0.46064516},
#    'waiverRank': 4}]}

# %%
params = {
            'view': 'mSettings',
        }

# %%
settings = requests.get(f'{ENDPOINT}/seasons/{SEASON_ID}/segments/0/leagues/{LEAGUE_ID}', cookies=auths, params=params)

# %%
settings.json().keys()
# Out:
# dict_keys(['draftDetail', 'gameId', 'id', 'members', 'scoringPeriodId', 'seasonId', 'segmentId', 'status', 'teams'])

# %%
params = {
            'scoringPeriodId': 0,
            'view': 'players_wl',
        }

# %%
players = requests.get(f'{ENDPOINT}/seasons/{SEASON_ID}/segments/0/leagues/{LEAGUE_ID}', cookies=auths, params=params)

# %%
players.json()
# Out:
# {'players': [{'player': {'defaultPositionId': 3,
#     'droppable': True,
#     'eligibleSlots': [2, 6, 7, 8, 10, 11, 12, 13],
#     'firstName': 'Metta',
#     'fullName': 'Metta World Peace',
#     'id': 25,
#     'lastName': 'World Peace',
#     'ownership': {'percentOwned': 0.2059005206341736},
#     'proTeamId': 13,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 3,
#     'droppable': True,
#     'eligibleSlots': [2, 6, 7, 8, 10, 11, 12, 13],
#     'firstName': 'Vince',
#     'fullName': 'Vince Carter',
#     'id': 136,
#     'lastName': 'Carter',
#     'ownership': {'percentOwned': 1.230034611575758},
#     'proTeamId': 1,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 5, 7, 8, 11, 12, 13],
#     'firstName': 'Jamal',
#     'fullName': 'Jamal Crawford',
#     'id': 165,
#     'lastName': 'Crawford',
#     'ownership': {'percentOwned': 0.5113171195638853},
#     'proTeamId': 21,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Kevin',
#     'fullName': 'Kevin Garnett',
#     'id': 261,
#     'lastName': 'Garnett',
#     'ownership': {'percentOwned': 0.17452605879959407},
#     'proTeamId': 16,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 5, 7, 8, 11, 12, 13],
#     'firstName': 'Manu',
#     'fullName': 'Manu Ginobili',
#     'id': 272,
#     'lastName': 'Ginobili',
#     'ownership': {'percentOwned': 0.07942188710325826},
#     'proTeamId': 24,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 1,
#     'droppable': True,
#     'eligibleSlots': [0, 5, 8, 11, 12, 13],
#     'firstName': 'Andre',
#     'fullName': 'Andre Miller',
#     'id': 557,
#     'lastName': 'Miller',
#     'ownership': {'percentOwned': 0.01078526536655195},
#     'proTeamId': 24,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [4, 9, 10, 11, 12, 13],
#     'firstName': 'Nazr',
#     'fullName': 'Nazr Mohammed',
#     'id': 568,
#     'lastName': 'Mohammed',
#     'ownership': {'percentOwned': 0.018139122164536545},
#     'proTeamId': 25,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Dirk',
#     'fullName': 'Dirk Nowitzki',
#     'id': 609,
#     'lastName': 'Nowitzki',
#     'ownership': {'percentOwned': 0.25835612946240355},
#     'proTeamId': 6,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 3,
#     'droppable': True,
#     'eligibleSlots': [2, 6, 7, 8, 10, 11, 12, 13],
#     'firstName': 'Paul',
#     'fullName': 'Paul Pierce',
#     'id': 662,
#     'lastName': 'Pierce',
#     'ownership': {'percentOwned': 0.10196978164740027},
#     'proTeamId': 12,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 5, 7, 8, 11, 12, 13],
#     'firstName': 'Jason',
#     'fullName': 'Jason Terry',
#     'id': 841,
#     'lastName': 'Terry',
#     'ownership': {'percentOwned': 0.03235643059545637},
#     'proTeamId': 15,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [4, 9, 10, 11, 12, 13],
#     'firstName': 'Tyson',
#     'fullName': 'Tyson Chandler',
#     'id': 984,
#     'lastName': 'Chandler',
#     'ownership': {'percentOwned': 1.0285221245011815},
#     'proTeamId': 10,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [4, 9, 10, 11, 12, 13],
#     'firstName': 'Pau',
#     'fullName': 'Pau Gasol',
#     'id': 996,
#     'lastName': 'Gasol',
#     'ownership': {'percentOwned': 0.2039365639630365},
#     'proTeamId': 22,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 3,
#     'droppable': True,
#     'eligibleSlots': [2, 6, 7, 8, 10, 11, 12, 13],
#     'firstName': 'Richard',
#     'fullName': 'Richard Jefferson',
#     'id': 1006,
#     'lastName': 'Jefferson',
#     'ownership': {'percentOwned': 0.016668137384671197},
#     'proTeamId': 7,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 5, 7, 8, 11, 12, 13],
#     'firstName': 'Joe',
#     'fullName': 'Joe Johnson',
#     'id': 1007,
#     'lastName': 'Johnson',
#     'ownership': {'percentOwned': 0.06226039552509535},
#     'proTeamId': 8,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 1,
#     'droppable': True,
#     'eligibleSlots': [0, 5, 8, 11, 12, 13],
#     'firstName': 'Tony',
#     'fullName': 'Tony Parker',
#     'id': 1015,
#     'lastName': 'Parker',
#     'ownership': {'percentOwned': 0.06128051769781351},
#     'proTeamId': 30,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Zach',
#     'fullName': 'Zach Randolph',
#     'id': 1017,
#     'lastName': 'Randolph',
#     'ownership': {'percentOwned': 0.13677610389101053},
#     'proTeamId': 6,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [4, 9, 10, 11, 12, 13],
#     'firstName': 'Chris',
#     'fullName': 'Chris Andersen',
#     'id': 1135,
#     'lastName': 'Andersen',
#     'ownership': {'percentOwned': 0.022062284279887042},
#     'proTeamId': 5,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 3,
#     'droppable': True,
#     'eligibleSlots': [2, 6, 7, 8, 10, 11, 12, 13],
#     'firstName': 'Caron',
#     'fullName': 'Caron Butler',
#     'id': 1705,
#     'lastName': 'Butler',
#     'ownership': {'percentOwned': 0.012746222705925033},
#     'proTeamId': 23,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 5, 7, 8, 11, 12, 13],
#     'firstName': 'Mike',
#     'fullName': 'Mike Dunleavy',
#     'id': 1708,
#     'lastName': 'Dunleavy',
#     'ownership': {'percentOwned': 0.007844252369209348},
#     'proTeamId': 1,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Drew',
#     'fullName': 'Drew Gooden',
#     'id': 1711,
#     'lastName': 'Gooden',
#     'ownership': {'percentOwned': 0.009805027037362055},
#     'proTeamId': 27,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [4, 9, 10, 11, 12, 13],
#     'firstName': 'Nene',
#     'fullName': 'Nene ',
#     'id': 1713,
#     'lastName': 'Hilario',
#     'ownership': {'percentOwned': 0.027453806519298556},
#     'proTeamId': 10,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 3,
#     'droppable': True,
#     'eligibleSlots': [2, 6, 7, 8, 10, 11, 12, 13],
#     'firstName': 'Tayshaun',
#     'fullName': 'Tayshaun Prince',
#     'id': 1724,
#     'lastName': 'Prince',
#     'ownership': {'percentOwned': 0.008824308027178868},
#     'proTeamId': 16,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': "Amar'e",
#     'fullName': "Amar'e Stoudemire",
#     'id': 1727,
#     'lastName': 'Stoudemire',
#     'ownership': {'percentOwned': 0.03872985679758012},
#     'proTeamId': 14,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 3,
#     'droppable': True,
#     'eligibleSlots': [2, 6, 7, 8, 10, 11, 12, 13],
#     'firstName': 'Matt',
#     'fullName': 'Matt Barnes',
#     'id': 1765,
#     'lastName': 'Barnes',
#     'ownership': {'percentOwned': 0.018629094724044278},
#     'proTeamId': 9,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 5, 7, 8, 11, 12, 13],
#     'firstName': 'Rasual',
#     'fullName': 'Rasual Butler',
#     'id': 1767,
#     'lastName': 'Butler',
#     'ownership': {'percentOwned': 0.007353590022649057},
#     'proTeamId': 16,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Luis',
#     'fullName': 'Luis Scola',
#     'id': 1781,
#     'lastName': 'Scola',
#     'ownership': {'percentOwned': 0.020100305426592215},
#     'proTeamId': 17,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 3,
#     'droppable': False,
#     'eligibleSlots': [2, 6, 7, 8, 10, 11, 12, 13, 3, 9],
#     'firstName': 'LeBron',
#     'fullName': 'LeBron James',
#     'id': 1966,
#     'lastName': 'James',
#     'ownership': {'percentOwned': 99.3735263408154},
#     'proTeamId': 13,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13, 2, 7],
#     'firstName': 'Carmelo',
#     'fullName': 'Carmelo Anthony',
#     'id': 1975,
#     'lastName': 'Anthony',
#     'ownership': {'percentOwned': 1.283452870610498},
#     'proTeamId': 4,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Chris',
#     'fullName': 'Chris Bosh',
#     'id': 1977,
#     'lastName': 'Bosh',
#     'ownership': {'percentOwned': 0.09657951631801624},
#     'proTeamId': 14,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Nick',
#     'fullName': 'Nick Collison',
#     'id': 1978,
#     'lastName': 'Collison',
#     'ownership': {'percentOwned': 0.012256043455027675},
#     'proTeamId': 25,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 5, 7, 8, 11, 12, 13],
#     'firstName': 'Kirk',
#     'fullName': 'Kirk Hinrich',
#     'id': 1981,
#     'lastName': 'Hinrich',
#     'ownership': {'percentOwned': 0.011765974761984136},
#     'proTeamId': 1,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [4, 9, 10, 11, 12, 13],
#     'firstName': 'Chris',
#     'fullName': 'Chris Kaman',
#     'id': 1982,
#     'lastName': 'Kaman',
#     'ownership': {'percentOwned': 0.014707396349624226},
#     'proTeamId': 22,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 5, 7, 8, 11, 12, 13],
#     'firstName': 'Dwyane',
#     'fullName': 'Dwyane Wade',
#     'id': 1987,
#     'lastName': 'Wade',
#     'ownership': {'percentOwned': 0.4608227156184584},
#     'proTeamId': 14,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 1,
#     'droppable': True,
#     'eligibleSlots': [0, 5, 8, 11, 12, 13],
#     'firstName': 'Steve',
#     'fullName': 'Steve Blake',
#     'id': 1994,
#     'lastName': 'Blake',
#     'ownership': {'percentOwned': 0.012256223710400142},
#     'proTeamId': 8,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Matt',
#     'fullName': 'Matt Bonner',
#     'id': 1996,
#     'lastName': 'Bonner',
#     'ownership': {'percentOwned': 0.019609669528044278},
#     'proTeamId': 24,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 5, 7, 8, 11, 12, 13],
#     'firstName': 'Dahntay',
#     'fullName': 'Dahntay Jones',
#     'id': 2008,
#     'lastName': 'Jones',
#     'ownership': {'percentOwned': 0.005882987380992068},
#     'proTeamId': 5,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 3,
#     'droppable': True,
#     'eligibleSlots': [2, 6, 7, 8, 10, 11, 12, 13],
#     'firstName': 'James',
#     'fullName': 'James Jones',
#     'id': 2009,
#     'lastName': 'Jones',
#     'ownership': {'percentOwned': 0.012256223710400142},
#     'proTeamId': 5,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 3,
#     'droppable': True,
#     'eligibleSlots': [2, 6, 7, 8, 10, 11, 12, 13, 1, 5],
#     'firstName': 'Kyle',
#     'fullName': 'Kyle Korver',
#     'id': 2011,
#     'lastName': 'Korver',
#     'ownership': {'percentOwned': 2.6507240834975634},
#     'proTeamId': 15,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [4, 9, 10, 11, 12, 13],
#     'firstName': 'Zaza',
#     'fullName': 'Zaza Pachulia',
#     'id': 2016,
#     'lastName': 'Pachulia',
#     'ownership': {'percentOwned': 0.0759897046206643},
#     'proTeamId': 8,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [4, 9, 10, 11, 12, 13],
#     'firstName': 'Kendrick',
#     'fullName': 'Kendrick Perkins',
#     'id': 2018,
#     'lastName': 'Perkins',
#     'ownership': {'percentOwned': 0.03578869959553867},
#     'proTeamId': 5,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 5, 7, 8, 11, 12, 13],
#     'firstName': 'Leandro',
#     'fullName': 'Leandro Barbosa',
#     'id': 2166,
#     'lastName': 'Barbosa',
#     'ownership': {'percentOwned': 0.012255983371081762},
#     'proTeamId': 21,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Boris',
#     'fullName': 'Boris Diaw',
#     'id': 2167,
#     'lastName': 'Diaw',
#     'ownership': {'percentOwned': 0.009804834764022139},
#     'proTeamId': 26,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'David',
#     'fullName': 'David West',
#     'id': 2177,
#     'lastName': 'West',
#     'ownership': {'percentOwned': 0.027943779077463097},
#     'proTeamId': 9,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 1,
#     'droppable': True,
#     'eligibleSlots': [0, 5, 8, 11, 12, 13],
#     'firstName': 'Mo',
#     'fullName': 'Mo Williams',
#     'id': 2178,
#     'lastName': 'Williams',
#     'ownership': {'percentOwned': 0.021570953730304248},
#     'proTeamId': 1,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Udonis',
#     'fullName': 'Udonis Haslem',
#     'id': 2184,
#     'lastName': 'Haslem',
#     'ownership': {'percentOwned': 0.03725910274197581},
#     'proTeamId': 14,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 3,
#     'droppable': True,
#     'eligibleSlots': [2, 6, 7, 8, 10, 11, 12, 13],
#     'firstName': 'Tony',
#     'fullName': 'Tony Allen',
#     'id': 2367,
#     'lastName': 'Allen',
#     'ownership': {'percentOwned': 0.00882452433362585},
#     'proTeamId': 3,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 5, 7, 8, 11, 12, 13, 0],
#     'firstName': 'Devin',
#     'fullName': 'Devin Harris',
#     'id': 2382,
#     'lastName': 'Harris',
#     'ownership': {'percentOwned': 0.026963163416379877},
#     'proTeamId': 6,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [4, 9, 10, 11, 12, 13],
#     'firstName': 'Dwight',
#     'fullName': 'Dwight Howard',
#     'id': 2384,
#     'lastName': 'Howard',
#     'ownership': {'percentOwned': 63.092927034923626},
#     'proTeamId': 13,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 3,
#     'droppable': True,
#     'eligibleSlots': [2, 6, 7, 8, 10, 11, 12, 13],
#     'firstName': 'Andre',
#     'fullName': 'Andre Iguodala',
#     'id': 2386,
#     'lastName': 'Iguodala',
#     'ownership': {'percentOwned': 1.5873794023060632},
#     'proTeamId': 29,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [4, 9, 10, 11, 12, 13],
#     'firstName': 'Al',
#     'fullName': 'Al Jefferson',
#     'id': 2389,
#     'lastName': 'Jefferson',
#     'ownership': {'percentOwned': 0.008334354700330922},
#     'proTeamId': 11,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 1,
#     'droppable': True,
#     'eligibleSlots': [0, 5, 8, 11, 12, 13],
#     'firstName': 'Shaun',
#     'fullName': 'Shaun Livingston',
#     'id': 2393,
#     'lastName': 'Livingston',
#     'ownership': {'percentOwned': 0.11863791903207145},
#     'proTeamId': 9,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 5, 7, 8, 11, 12, 13],
#     'firstName': 'Kevin',
#     'fullName': 'Kevin Martin',
#     'id': 2394,
#     'lastName': 'Martin',
#     'ownership': {'percentOwned': 0.00980478669686541},
#     'proTeamId': 24,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [4, 9, 10, 11, 12, 13],
#     'firstName': 'Emeka',
#     'fullName': 'Emeka Okafor',
#     'id': 2399,
#     'lastName': 'Okafor',
#     'ownership': {'percentOwned': 0.017649221718347836},
#     'proTeamId': 20,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 3,
#     'droppable': True,
#     'eligibleSlots': [2, 6, 7, 8, 10, 11, 12, 13],
#     'firstName': 'Josh',
#     'fullName': 'Josh Smith',
#     'id': 2411,
#     'lastName': 'Smith',
#     'ownership': {'percentOwned': 0.015197419380141386},
#     'proTeamId': 3,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [4, 9, 10, 11, 12, 13],
#     'firstName': 'Anderson',
#     'fullName': 'Anderson Varejao',
#     'id': 2419,
#     'lastName': 'Varejao',
#     'ownership': {'percentOwned': 0.032356271969173296},
#     'proTeamId': 9,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 5, 7, 8, 11, 12, 13],
#     'firstName': 'Sasha',
#     'fullName': 'Sasha Vujacic',
#     'id': 2421,
#     'lastName': 'Vujacic',
#     'ownership': {'percentOwned': 0.018629460039808216},
#     'proTeamId': 18,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 3,
#     'droppable': True,
#     'eligibleSlots': [2, 6, 7, 8, 10, 11, 12, 13],
#     'firstName': 'Trevor',
#     'fullName': 'Trevor Ariza',
#     'id': 2426,
#     'lastName': 'Ariza',
#     'ownership': {'percentOwned': 4.187970920000589},
#     'proTeamId': 23,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 3,
#     'droppable': True,
#     'eligibleSlots': [2, 6, 7, 8, 10, 11, 12, 13],
#     'firstName': 'Luol',
#     'fullName': 'Luol Deng',
#     'id': 2429,
#     'lastName': 'Deng',
#     'ownership': {'percentOwned': 0.027943368107302535},
#     'proTeamId': 16,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Kris',
#     'fullName': 'Kris Humphries',
#     'id': 2433,
#     'lastName': 'Humphries',
#     'ownership': {'percentOwned': 0.0176490486672517},
#     'proTeamId': 20,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 1,
#     'droppable': True,
#     'eligibleSlots': [0, 5, 8, 11, 12, 13],
#     'firstName': 'Jameer',
#     'fullName': 'Jameer Nelson',
#     'id': 2439,
#     'lastName': 'Nelson',
#     'ownership': {'percentOwned': 0.006373236329408074},
#     'proTeamId': 8,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 5, 7, 8, 11, 12, 13],
#     'firstName': 'JR',
#     'fullName': 'JR Smith',
#     'id': 2444,
#     'lastName': 'Smith',
#     'ownership': {'percentOwned': 0.171587131945602},
#     'proTeamId': 5,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 1,
#     'droppable': True,
#     'eligibleSlots': [0, 5, 8, 11, 12, 13],
#     'firstName': 'Beno',
#     'fullName': 'Beno Udrih',
#     'id': 2448,
#     'lastName': 'Udrih',
#     'ownership': {'percentOwned': 0.012746472658816147},
#     'proTeamId': 8,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 3,
#     'droppable': True,
#     'eligibleSlots': [2, 6, 7, 8, 10, 11, 12, 13],
#     'firstName': 'Damien',
#     'fullName': 'Damien Wilkins',
#     'id': 2506,
#     'lastName': 'Wilkins',
#     'ownership': {'percentOwned': 0.010785476865152124},
#     'proTeamId': 11,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Brandon',
#     'fullName': 'Brandon Bass',
#     'id': 2745,
#     'lastName': 'Bass',
#     'ownership': {'percentOwned': 0.005392659120212176},
#     'proTeamId': 12,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [4, 9, 10, 11, 12, 13],
#     'firstName': 'Andrew',
#     'fullName': 'Andrew Bogut',
#     'id': 2747,
#     'lastName': 'Bogut',
#     'ownership': {'percentOwned': 0.06177106466842175},
#     'proTeamId': 9,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 5, 7, 8, 11, 12, 13],
#     'firstName': 'Monta',
#     'fullName': 'Monta Ellis',
#     'id': 2751,
#     'lastName': 'Ellis',
#     'ownership': {'percentOwned': 0.012256223710400142},
#     'proTeamId': 11,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 1,
#     'droppable': True,
#     'eligibleSlots': [0, 5, 8, 11, 12, 13],
#     'firstName': 'Raymond',
#     'fullName': 'Raymond Felton',
#     'id': 2753,
#     'lastName': 'Felton',
#     'ownership': {'percentOwned': 0.028433881420909687},
#     'proTeamId': 25,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [4, 9, 10, 11, 12, 13],
#     'firstName': 'Channing',
#     'fullName': 'Channing Frye',
#     'id': 2754,
#     'lastName': 'Frye',
#     'ownership': {'percentOwned': 0.01666862768168804},
#     'proTeamId': 5,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [4, 9, 10, 11, 12, 13],
#     'firstName': 'Marcin',
#     'fullName': 'Marcin Gortat',
#     'id': 2758,
#     'lastName': 'Gortat',
#     'ownership': {'percentOwned': 0.2519867241235617},
#     'proTeamId': 12,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 5, 7, 8, 11, 12, 13, 2, 6, 10],
#     'firstName': 'Gerald',
#     'fullName': 'Gerald Green',
#     'id': 2761,
#     'lastName': 'Green',
#     'ownership': {'percentOwned': 0.19805280754561588},
#     'proTeamId': 10,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Ersan',
#     'fullName': 'Ersan Ilyasova',
#     'id': 2767,
#     'lastName': 'Ilyasova',
#     'ownership': {'percentOwned': 2.9365912010118738},
#     'proTeamId': 15,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 1,
#     'droppable': True,
#     'eligibleSlots': [0, 5, 8, 11, 12, 13],
#     'firstName': 'Jarrett',
#     'fullName': 'Jarrett Jack',
#     'id': 2768,
#     'lastName': 'Jack',
#     'ownership': {'percentOwned': 0.008334068692335599},
#     'proTeamId': 3,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [4, 9, 10, 11, 12, 13],
#     'firstName': 'Amir',
#     'fullName': 'Amir Johnson',
#     'id': 2769,
#     'lastName': 'Johnson',
#     'ownership': {'percentOwned': 0.020100502512562814},
#     'proTeamId': 20,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'David',
#     'fullName': 'David Lee',
#     'id': 2772,
#     'lastName': 'Lee',
#     'ownership': {'percentOwned': 0.015197493884234315},
#     'proTeamId': 24,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [4, 9, 10, 11, 12, 13],
#     'firstName': 'Ian',
#     'fullName': 'Ian Mahinmi',
#     'id': 2774,
#     'lastName': 'Mahinmi',
#     'ownership': {'percentOwned': 0.020100502512562814},
#     'proTeamId': 27,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 3,
#     'droppable': True,
#     'eligibleSlots': [2, 6, 7, 8, 10, 11, 12, 13],
#     'firstName': 'C.J.',
#     'fullName': 'C.J. Miles',
#     'id': 2778,
#     'lastName': 'Miles',
#     'ownership': {'percentOwned': 0.23629535939445637},
#     'proTeamId': 27,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 1,
#     'droppable': True,
#     'eligibleSlots': [0, 5, 8, 11, 12, 13],
#     'firstName': 'Chris',
#     'fullName': 'Chris Paul',
#     'id': 2779,
#     'lastName': 'Paul',
#     'ownership': {'percentOwned': 90.22020471391035},
#     'proTeamId': 25,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 1,
#     'droppable': True,
#     'eligibleSlots': [0, 5, 8, 11, 12, 13],
#     'firstName': 'Nate',
#     'fullName': 'Nate Robinson',
#     'id': 2782,
#     'lastName': 'Robinson',
#     'ownership': {'percentOwned': 0.04216058279652126},
#     'proTeamId': 3,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Charlie',
#     'fullName': 'Charlie Villanueva',
#     'id': 2792,
#     'lastName': 'Villanueva',
#     'ownership': {'percentOwned': 0.01617797736063653},
#     'proTeamId': 6,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Marvin',
#     'fullName': 'Marvin Williams',
#     'id': 2797,
#     'lastName': 'Williams',
#     'ownership': {'percentOwned': 2.164939356205081},
#     'proTeamId': 30,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 1,
#     'droppable': True,
#     'eligibleSlots': [0, 5, 8, 11, 12, 13],
#     'firstName': 'Deron',
#     'fullName': 'Deron Williams',
#     'id': 2798,
#     'lastName': 'Williams',
#     'ownership': {'percentOwned': 0.029905185853376346},
#     'proTeamId': 5,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 5, 7, 8, 11, 12, 13],
#     'firstName': 'Lou',
#     'fullName': 'Lou Williams',
#     'id': 2799,
#     'lastName': 'Williams',
#     'ownership': {'percentOwned': 93.4698099425955},
#     'proTeamId': 12,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 1,
#     'droppable': True,
#     'eligibleSlots': [0, 5, 8, 11, 12, 13],
#     'firstName': 'Jose',
#     'fullName': 'Jose Calderon',
#     'id': 2806,
#     'lastName': 'Calderon',
#     'ownership': {'percentOwned': 0.02059116246917454},
#     'proTeamId': 8,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 1,
#     'droppable': True,
#     'eligibleSlots': [0, 5, 8, 11, 12, 13],
#     'firstName': 'Ronnie',
#     'fullName': 'Ronnie Price',
#     'id': 2807,
#     'lastName': 'Price',
#     'ownership': {'percentOwned': 0.0034316753439028935},
#     'proTeamId': 21,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Chuck',
#     'fullName': 'Chuck Hayes',
#     'id': 2834,
#     'lastName': 'Hayes',
#     'ownership': {'percentOwned': 0.007843867811217712},
#     'proTeamId': 10,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 1,
#     'droppable': True,
#     'eligibleSlots': [0, 5, 8, 11, 12, 13],
#     'firstName': 'John',
#     'fullName': 'John Lucas III',
#     'id': 2866,
#     'lastName': 'Lucas III',
#     'ownership': {'percentOwned': 0.005392632683275975},
#     'proTeamId': 16,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13, 4],
#     'firstName': 'LaMarcus',
#     'fullName': 'LaMarcus Aldridge',
#     'id': 2983,
#     'lastName': 'Aldridge',
#     'ownership': {'percentOwned': 98.82933142470561},
#     'proTeamId': 24,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Andrea',
#     'fullName': 'Andrea Bargnani',
#     'id': 2987,
#     'lastName': 'Bargnani',
#     'ownership': {'percentOwned': 0.012746535148570673},
#     'proTeamId': 17,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 1,
#     'droppable': True,
#     'eligibleSlots': [0, 5, 8, 11, 12, 13],
#     'firstName': 'Jordan',
#     'fullName': 'Jordan Farmar',
#     'id': 3002,
#     'lastName': 'Farmar',
#     'ownership': {'percentOwned': 0.005392632683275975},
#     'proTeamId': 23,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 5, 7, 8, 11, 12, 13],
#     'firstName': 'Randy',
#     'fullName': 'Randy Foye',
#     'id': 3003,
#     'lastName': 'Foye',
#     'ownership': {'percentOwned': 0.008334232123072096},
#     'proTeamId': 17,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 3,
#     'droppable': True,
#     'eligibleSlots': [2, 6, 7, 8, 10, 11, 12, 13, 3, 9],
#     'firstName': 'Rudy',
#     'fullName': 'Rudy Gay',
#     'id': 3005,
#     'lastName': 'Gay',
#     'ownership': {'percentOwned': 65.4821140562879},
#     'proTeamId': 24,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [4, 9, 10, 11, 12, 13],
#     'firstName': 'Ryan',
#     'fullName': 'Ryan Hollins',
#     'id': 3008,
#     'lastName': 'Hollins',
#     'ownership': {'percentOwned': 0.01176614781223189},
#     'proTeamId': 27,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 1,
#     'droppable': True,
#     'eligibleSlots': [0, 5, 8, 11, 12, 13],
#     'firstName': 'Kyle',
#     'fullName': 'Kyle Lowry',
#     'id': 3012,
#     'lastName': 'Lowry',
#     'ownership': {'percentOwned': 93.99278388924839},
#     'proTeamId': 28,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Paul',
#     'fullName': 'Paul Millsap',
#     'id': 3015,
#     'lastName': 'Millsap',
#     'ownership': {'percentOwned': 75.93240778869345},
#     'proTeamId': 7,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Steve',
#     'fullName': 'Steve Novak',
#     'id': 3018,
#     'lastName': 'Novak',
#     'ownership': {'percentOwned': 0.017158797315383598},
#     'proTeamId': 15,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 5, 7, 8, 11, 12, 13],
#     'firstName': 'JJ',
#     'fullName': 'JJ Redick',
#     'id': 3024,
#     'lastName': 'Redick',
#     'ownership': {'percentOwned': 31.175394992916353},
#     'proTeamId': 3,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 1,
#     'droppable': True,
#     'eligibleSlots': [0, 5, 8, 11, 12, 13],
#     'firstName': 'Sergio',
#     'fullName': 'Sergio Rodriguez',
#     'id': 3025,
#     'lastName': 'Rodriguez',
#     'ownership': {'percentOwned': 0.008334232123072096},
#     'proTeamId': 20,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 1,
#     'droppable': True,
#     'eligibleSlots': [0, 5, 8, 11, 12, 13],
#     'firstName': 'Rajon',
#     'fullName': 'Rajon Rondo',
#     'id': 3026,
#     'lastName': 'Rondo',
#     'ownership': {'percentOwned': 14.598622447729},
#     'proTeamId': 13,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 3,
#     'droppable': True,
#     'eligibleSlots': [2, 6, 7, 8, 10, 11, 12, 13, 1, 5],
#     'firstName': 'Thabo',
#     'fullName': 'Thabo Sefolosha',
#     'id': 3028,
#     'lastName': 'Sefolosha',
#     'ownership': {'percentOwned': 0.06422135286446844},
#     'proTeamId': 10,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 3,
#     'droppable': True,
#     'eligibleSlots': [2, 6, 7, 8, 10, 11, 12, 13, 3, 9],
#     'firstName': 'PJ',
#     'fullName': 'PJ Tucker',
#     'id': 3033,
#     'lastName': 'Tucker',
#     'ownership': {'percentOwned': 44.35838104949408},
#     'proTeamId': 10,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Lou',
#     'fullName': 'Lou Amundson',
#     'id': 3041,
#     'lastName': 'Amundson',
#     'ownership': {'percentOwned': 0.004902681766926509},
#     'proTeamId': 18,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 1,
#     'droppable': True,
#     'eligibleSlots': [0, 5, 8, 11, 12, 13],
#     'firstName': 'J.J.',
#     'fullName': 'J.J. Barea',
#     'id': 3055,
#     'lastName': 'Barea',
#     'ownership': {'percentOwned': 0.36963502218300365},
#     'proTeamId': 6,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 5, 7, 8, 11, 12, 13],
#     'firstName': 'Arron',
#     'fullName': 'Arron Afflalo',
#     'id': 3187,
#     'lastName': 'Afflalo',
#     'ownership': {'percentOwned': 0.009804978968320112},
#     'proTeamId': 19,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 5, 7, 8, 11, 12, 13, 2, 6, 10],
#     'firstName': 'Marco',
#     'fullName': 'Marco Belinelli',
#     'id': 3190,
#     'lastName': 'Belinelli',
#     'ownership': {'percentOwned': 0.5598450866485281},
#     'proTeamId': 24,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 3,
#     'droppable': True,
#     'eligibleSlots': [2, 6, 7, 8, 10, 11, 12, 13],
#     'firstName': 'Corey',
#     'fullName': 'Corey Brewer',
#     'id': 3191,
#     'lastName': 'Brewer',
#     'ownership': {'percentOwned': 0.01715837671951447},
#     'proTeamId': 23,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 1,
#     'droppable': True,
#     'eligibleSlots': [0, 5, 8, 11, 12, 13],
#     'firstName': 'Aaron',
#     'fullName': 'Aaron Brooks',
#     'id': 3192,
#     'lastName': 'Brooks',
#     'ownership': {'percentOwned': 0.006373111352962517},
#     'proTeamId': 16,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 3,
#     'droppable': True,
#     'eligibleSlots': [2, 6, 7, 8, 10, 11, 12, 13, 3, 9],
#     'firstName': 'Wilson',
#     'fullName': 'Wilson Chandler',
#     'id': 3194,
#     'lastName': 'Chandler',
#     'ownership': {'percentOwned': 0.1323633226135383},
#     'proTeamId': 17,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 1,
#     'droppable': True,
#     'eligibleSlots': [0, 5, 8, 11, 12, 13],
#     'firstName': 'Mike',
#     'fullName': 'Mike Conley',
#     'id': 3195,
#     'lastName': 'Conley',
#     'ownership': {'percentOwned': 80.72829598544976},
#     'proTeamId': 26,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13, 2, 7],
#     'firstName': 'Jared',
#     'fullName': 'Jared Dudley',
#     'id': 3201,
#     'lastName': 'Dudley',
#     'ownership': {'percentOwned': 0.17991342585556921},
#     'proTeamId': 13,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 3,
#     'droppable': True,
#     'eligibleSlots': [2, 6, 7, 8, 10, 11, 12, 13],
#     'firstName': 'Kevin',
#     'fullName': 'Kevin Durant',
#     'id': 3202,
#     'lastName': 'Durant',
#     'ownership': {'percentOwned': 9.17870133435297},
#     'proTeamId': 17,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [4, 9, 10, 11, 12, 13],
#     'firstName': 'Marc',
#     'fullName': 'Marc Gasol',
#     'id': 3206,
#     'lastName': 'Gasol',
#     'ownership': {'percentOwned': 62.2433022035934},
#     'proTeamId': 28,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Jeff',
#     'fullName': 'Jeff Green',
#     'id': 3209,
#     'lastName': 'Green',
#     'ownership': {'percentOwned': 10.560193741635333},
#     'proTeamId': 26,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [4, 9, 10, 11, 12, 13],
#     'firstName': 'Spencer',
#     'fullName': 'Spencer Hawes',
#     'id': 3211,
#     'lastName': 'Hawes',
#     'ownership': {'percentOwned': 0.004412305429586959},
#     'proTeamId': 15,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [3, 4, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Al',
#     'fullName': 'Al Horford',
#     'id': 3213,
#     'lastName': 'Horford',
#     'ownership': {'percentOwned': 88.13822720520828},
#     'proTeamId': 20,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Carl',
#     'fullName': 'Carl Landry',
#     'id': 3217,
#     'lastName': 'Landry',
#     'ownership': {'percentOwned': 0.0063732675742853365},
#     'proTeamId': 20,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Josh',
#     'fullName': 'Josh McRoberts',
#     'id': 3220,
#     'lastName': 'McRoberts',
#     'ownership': {'percentOwned': 0.0068633843348154975},
#     'proTeamId': 6,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [4, 9, 10, 11, 12, 13],
#     'firstName': 'Joakim',
#     'fullName': 'Joakim Noah',
#     'id': 3224,
#     'lastName': 'Noah',
#     'ownership': {'percentOwned': 0.31326447071050734},
#     'proTeamId': 29,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 1,
#     'droppable': True,
#     'eligibleSlots': [0, 5, 8, 11, 12, 13],
#     'firstName': 'Ramon',
#     'fullName': 'Ramon Sessions',
#     'id': 3231,
#     'lastName': 'Sessions',
#     'ownership': {'percentOwned': 0.002941493690496034},
#     'proTeamId': 27,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [4, 9, 10, 11, 12, 13],
#     'firstName': 'Jason',
#     'fullName': 'Jason Smith',
#     'id': 3232,
#     'lastName': 'Smith',
#     'ownership': {'percentOwned': 0.00931468435476201},
#     'proTeamId': 3,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Tiago',
#     'fullName': 'Tiago Splitter',
#     'id': 3233,
#     'lastName': 'Splitter',
#     'ownership': {'percentOwned': 0.010295278389230158},
#     'proTeamId': 20,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 5, 7, 8, 11, 12, 13],
#     'firstName': 'Rodney',
#     'fullName': 'Rodney Stuckey',
#     'id': 3235,
#     'lastName': 'Stuckey',
#     'ownership': {'percentOwned': 0.005392738432576062},
#     'proTeamId': 11,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Brandan',
#     'fullName': 'Brandan Wright',
#     'id': 3242,
#     'lastName': 'Wright',
#     'ownership': {'percentOwned': 0.03676795011324529},
#     'proTeamId': 10,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 5, 7, 8, 11, 12, 13],
#     'firstName': 'Nick',
#     'fullName': 'Nick Young',
#     'id': 3243,
#     'lastName': 'Young',
#     'ownership': {'percentOwned': 0.0813797295839829},
#     'proTeamId': 7,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13, 2, 7],
#     'firstName': 'Thaddeus',
#     'fullName': 'Thaddeus Young',
#     'id': 3244,
#     'lastName': 'Young',
#     'ownership': {'percentOwned': 38.968144248021886},
#     'proTeamId': 4,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [4, 9, 10, 11, 12, 13],
#     'firstName': 'Joel',
#     'fullName': 'Joel Anthony',
#     'id': 3247,
#     'lastName': 'Anthony',
#     'ownership': {'percentOwned': 0.015197940924132859},
#     'proTeamId': 15,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Anthony',
#     'fullName': 'Anthony Tolliver',
#     'id': 3276,
#     'lastName': 'Tolliver',
#     'ownership': {'percentOwned': 0.3789568636294557},
#     'proTeamId': 22,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 1,
#     'droppable': True,
#     'eligibleSlots': [0, 5, 8, 11, 12, 13],
#     'firstName': 'C.J.',
#     'fullName': 'C.J. Watson',
#     'id': 3277,
#     'lastName': 'Watson',
#     'ownership': {'percentOwned': 0.009804978968320112},
#     'proTeamId': 19,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [4, 9, 10, 11, 12, 13],
#     'firstName': 'Alexis',
#     'fullName': 'Alexis Ajinca',
#     'id': 3410,
#     'lastName': 'Ajinca',
#     'ownership': {'percentOwned': 0.010785423989724433},
#     'proTeamId': 12,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Ryan',
#     'fullName': 'Ryan Anderson',
#     'id': 3412,
#     'lastName': 'Anderson',
#     'ownership': {'percentOwned': 0.024511365920377278},
#     'proTeamId': 10,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Darrell',
#     'fullName': 'Darrell Arthur',
#     'id': 3413,
#     'lastName': 'Arthur',
#     'ownership': {'percentOwned': 0.0034316921674077488},
#     'proTeamId': 21,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [4, 9, 10, 11, 12, 13],
#     'firstName': 'Omer',
#     'fullName': 'Omer Asik',
#     'id': 3414,
#     'lastName': 'Asik',
#     'ownership': {'percentOwned': 0.015197940924132859},
#     'proTeamId': 4,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 1,
#     'droppable': True,
#     'eligibleSlots': [0, 5, 8, 11, 12, 13],
#     'firstName': 'D.J.',
#     'fullName': 'D.J. Augustin',
#     'id': 3415,
#     'lastName': 'Augustin',
#     'ownership': {'percentOwned': 10.93386148709929},
#     'proTeamId': 19,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 5, 7, 8, 11, 12, 13, 2, 6, 10],
#     'firstName': 'Nicolas',
#     'fullName': 'Nicolas Batum',
#     'id': 3416,
#     'lastName': 'Batum',
#     'ownership': {'percentOwned': 21.15772083515126},
#     'proTeamId': 30,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 1,
#     'droppable': True,
#     'eligibleSlots': [0, 5, 8, 11, 12, 13],
#     'firstName': 'Jerryd',
#     'fullName': 'Jerryd Bayless',
#     'id': 3417,
#     'lastName': 'Bayless',
#     'ownership': {'percentOwned': 0.02059075867140581},
#     'proTeamId': 16,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Michael',
#     'fullName': 'Michael Beasley',
#     'id': 3418,
#     'lastName': 'Beasley',
#     'ownership': {'percentOwned': 0.07255542155680403},
#     'proTeamId': 12,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 1,
#     'droppable': True,
#     'eligibleSlots': [0, 5, 8, 11, 12, 13],
#     'firstName': 'Mario',
#     'fullName': 'Mario Chalmers',
#     'id': 3419,
#     'lastName': 'Chalmers',
#     'ownership': {'percentOwned': 0.011275504701395222},
#     'proTeamId': 29,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 1,
#     'droppable': True,
#     'eligibleSlots': [0, 5, 8, 11, 12, 13],
#     'firstName': 'Goran',
#     'fullName': 'Goran Dragic',
#     'id': 3423,
#     'lastName': 'Dragic',
#     'ownership': {'percentOwned': 52.41879344660908},
#     'proTeamId': 14,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 3,
#     'droppable': True,
#     'eligibleSlots': [2, 6, 7, 8, 10, 11, 12, 13, 3, 9],
#     'firstName': 'Danilo',
#     'fullName': 'Danilo Gallinari',
#     'id': 3428,
#     'lastName': 'Gallinari',
#     'ownership': {'percentOwned': 91.49284534273235},
#     'proTeamId': 25,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 2, 5, 6, 7, 8, 10, 11, 12, 13],
#     'firstName': 'Eric',
#     'fullName': 'Eric Gordon',
#     'id': 3431,
#     'lastName': 'Gordon',
#     'ownership': {'percentOwned': 18.21586669738758},
#     'proTeamId': 10,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [4, 9, 10, 11, 12, 13],
#     'firstName': 'Roy',
#     'fullName': 'Roy Hibbert',
#     'id': 3436,
#     'lastName': 'Hibbert',
#     'ownership': {'percentOwned': 0.025002573794361185},
#     'proTeamId': 7,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'JJ',
#     'fullName': 'JJ Hickson',
#     'id': 3437,
#     'lastName': 'Hickson',
#     'ownership': {'percentOwned': 0.011275781092966364},
#     'proTeamId': 27,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 1,
#     'droppable': True,
#     'eligibleSlots': [0, 5, 8, 11, 12, 13],
#     'firstName': 'George',
#     'fullName': 'George Hill',
#     'id': 3438,
#     'lastName': 'Hill',
#     'ownership': {'percentOwned': 4.657365009952054},
#     'proTeamId': 15,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13, 4],
#     'firstName': 'Serge',
#     'fullName': 'Serge Ibaka',
#     'id': 3439,
#     'lastName': 'Ibaka',
#     'ownership': {'percentOwned': 84.24615897481151},
#     'proTeamId': 28,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [4, 9, 10, 11, 12, 13],
#     'firstName': 'DeAndre',
#     'fullName': 'DeAndre Jordan',
#     'id': 3442,
#     'lastName': 'Jordan',
#     'ownership': {'percentOwned': 80.56841135057753},
#     'proTeamId': 17,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [4, 9, 10, 11, 12, 13],
#     'firstName': 'Sasha',
#     'fullName': 'Sasha Kaun',
#     'id': 3443,
#     'lastName': 'Kaun',
#     'ownership': {'percentOwned': 0.00539281774727295},
#     'proTeamId': 5,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [4, 9, 10, 11, 12, 13],
#     'firstName': 'Kosta',
#     'fullName': 'Kosta Koufos',
#     'id': 3444,
#     'lastName': 'Koufos',
#     'ownership': {'percentOwned': 0.021570847979448866},
#     'proTeamId': 23,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 5, 7, 8, 11, 12, 13],
#     'firstName': 'Courtney',
#     'fullName': 'Courtney Lee',
#     'id': 3445,
#     'lastName': 'Lee',
#     'ownership': {'percentOwned': 0.05245535167146282},
#     'proTeamId': 6,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [4, 9, 10, 11, 12, 13],
#     'firstName': 'Robin',
#     'fullName': 'Robin Lopez',
#     'id': 3447,
#     'lastName': 'Lopez',
#     'ownership': {'percentOwned': 2.067890340040005},
#     'proTeamId': 15,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [4, 9, 10, 11, 12, 13],
#     'firstName': 'Brook',
#     'fullName': 'Brook Lopez',
#     'id': 3448,
#     'lastName': 'Lopez',
#     'ownership': {'percentOwned': 58.03363074811256},
#     'proTeamId': 15,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13, 4],
#     'firstName': 'Kevin',
#     'fullName': 'Kevin Love',
#     'id': 3449,
#     'lastName': 'Love',
#     'ownership': {'percentOwned': 96.92665947641926},
#     'proTeamId': 5,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 5, 7, 8, 11, 12, 13],
#     'firstName': 'O.J.',
#     'fullName': 'O.J. Mayo',
#     'id': 3450,
#     'lastName': 'Mayo',
#     'ownership': {'percentOwned': 0.02941493690496034},
#     'proTeamId': 15,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 3,
#     'droppable': True,
#     'eligibleSlots': [2, 6, 7, 8, 10, 11, 12, 13],
#     'firstName': 'Luc',
#     'fullName': 'Luc Mbah a Moute',
#     'id': 3451,
#     'lastName': 'Mbah a Moute',
#     'ownership': {'percentOwned': 0.028924829760218065},
#     'proTeamId': 12,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [4, 9, 10, 11, 12, 13],
#     'firstName': 'JaVale',
#     'fullName': 'JaVale McGee',
#     'id': 3452,
#     'lastName': 'McGee',
#     'ownership': {'percentOwned': 30.43081810338066},
#     'proTeamId': 13,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [4, 9, 10, 11, 12, 13],
#     'firstName': 'Nikola',
#     'fullName': 'Nikola Pekovic',
#     'id': 3453,
#     'lastName': 'Pekovic',
#     'ownership': {'percentOwned': 0.00931468435476201},
#     'proTeamId': 16,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 1,
#     'droppable': True,
#     'eligibleSlots': [0, 5, 8, 11, 12, 13],
#     'firstName': 'Derrick',
#     'fullName': 'Derrick Rose',
#     'id': 3456,
#     'lastName': 'Rose',
#     'ownership': {'percentOwned': 76.3709274165874},
#     'proTeamId': 8,
#     'universeId': 1}},
# ...
#     'fullName': 'Zhaire Smith',
#     'id': 4277923,
#     'lastName': 'Smith',
#     'ownership': {'percentOwned': 0.17256593783704285},
#     'proTeamId': 20,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 5, 7, 8, 11, 12, 13],
#     'firstName': 'Jarrett',
#     'fullName': 'Jarrett Culver',
#     'id': 4277928,
#     'lastName': 'Culver',
#     'ownership': {'percentOwned': 28.347545517400324},
#     'proTeamId': 16,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Bruno',
#     'fullName': 'Bruno Fernando',
#     'id': 4277952,
#     'lastName': 'Fernando',
#     'ownership': {'percentOwned': 0.30456105934281513},
#     'proTeamId': 1,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 5, 7, 8, 11, 12, 13],
#     'firstName': 'Jordan',
#     'fullName': 'Jordan Poole',
#     'id': 4277956,
#     'lastName': 'Poole',
#     'ownership': {'percentOwned': 1.3192288641390437},
#     'proTeamId': 9,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13, 4],
#     'firstName': 'Jaren',
#     'fullName': 'Jaren Jackson Jr.',
#     'id': 4277961,
#     'lastName': 'Jackson Jr.',
#     'ownership': {'percentOwned': 86.09084848128322},
#     'proTeamId': 29,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 5, 7, 8, 11, 12, 13],
#     'firstName': 'Nickeil',
#     'fullName': 'Nickeil Alexander-Walker',
#     'id': 4278039,
#     'lastName': 'Alexander-Walker',
#     'ownership': {'percentOwned': 7.981089418215166},
#     'proTeamId': 3,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [3, 4, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Daniel',
#     'fullName': 'Daniel Gafford',
#     'id': 4278049,
#     'lastName': 'Gafford',
#     'ownership': {'percentOwned': 0.17320392922681374},
#     'proTeamId': 4,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Chuma',
#     'fullName': 'Chuma Okeke',
#     'id': 4278052,
#     'lastName': 'Okeke',
#     'ownership': {'percentOwned': 0.33399052467410173},
#     'proTeamId': 19,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Nicolas',
#     'fullName': 'Nicolas Claxton',
#     'id': 4278067,
#     'lastName': 'Claxton',
#     'ownership': {'percentOwned': 0.1132947183081322},
#     'proTeamId': 17,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 1,
#     'droppable': True,
#     'eligibleSlots': [0, 1, 5, 7, 8, 11, 12, 13],
#     'firstName': 'Shai',
#     'fullName': 'Shai Gilgeous-Alexander',
#     'id': 4278073,
#     'lastName': 'Gilgeous-Alexander',
#     'ownership': {'percentOwned': 83.94136967498407},
#     'proTeamId': 25,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 3,
#     'droppable': True,
#     'eligibleSlots': [2, 6, 7, 8, 10, 11, 12, 13],
#     'firstName': 'Kevin',
#     'fullName': 'Kevin Knox II',
#     'id': 4278075,
#     'lastName': 'Knox II',
#     'ownership': {'percentOwned': 11.839221895942309},
#     'proTeamId': 18,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Jarred',
#     'fullName': 'Jarred Vanderbilt',
#     'id': 4278077,
#     'lastName': 'Vanderbilt',
#     'ownership': {'percentOwned': 0.02108029139826063},
#     'proTeamId': 7,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'PJ',
#     'fullName': 'PJ Washington',
#     'id': 4278078,
#     'lastName': 'Washington',
#     'ownership': {'percentOwned': 29.560735426096937},
#     'proTeamId': 30,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 1,
#     'droppable': True,
#     'eligibleSlots': [0, 5, 8, 11, 12, 13],
#     'firstName': 'Tremont',
#     'fullName': 'Tremont Waters',
#     'id': 4278080,
#     'lastName': 'Waters',
#     'ownership': {'percentOwned': 0.05247747637287454},
#     'proTeamId': 2,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 3,
#     'droppable': True,
#     'eligibleSlots': [2, 6, 7, 8, 10, 11, 12, 13],
#     'firstName': 'Michael',
#     'fullName': 'Michael Porter Jr.',
#     'id': 4278104,
#     'lastName': 'Porter Jr.',
#     'ownership': {'percentOwned': 10.042895310929726},
#     'proTeamId': 7,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [4, 9, 10, 11, 12, 13],
#     'firstName': 'Deandre',
#     'fullName': 'Deandre Ayton',
#     'id': 4278129,
#     'lastName': 'Ayton',
#     'ownership': {'percentOwned': 85.07711464737085},
#     'proTeamId': 21,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 3,
#     'droppable': True,
#     'eligibleSlots': [2, 6, 7, 8, 10, 11, 12, 13],
#     'firstName': 'Troy',
#     'fullName': 'Troy Brown Jr.',
#     'id': 4278508,
#     'lastName': 'Brown Jr.',
#     'ownership': {'percentOwned': 2.5169134228845964},
#     'proTeamId': 27,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 3,
#     'droppable': True,
#     'eligibleSlots': [2, 6, 7, 8, 10, 11, 12, 13],
#     'firstName': 'KZ',
#     'fullName': 'KZ Okpala',
#     'id': 4278521,
#     'lastName': 'Okpala',
#     'ownership': {'percentOwned': 0.10004904364884748},
#     'proTeamId': 14,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 1,
#     'droppable': True,
#     'eligibleSlots': [0, 5, 8, 11, 12, 13],
#     'firstName': 'Jaylen',
#     'fullName': 'Jaylen Hands',
#     'id': 4278526,
#     'lastName': 'Hands',
#     'ownership': {'percentOwned': 0.03482099068170672},
#     'proTeamId': 17,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 5, 7, 8, 11, 12, 13],
#     'firstName': 'Jaylen',
#     'fullName': 'Jaylen Nowell',
#     'id': 4278541,
#     'lastName': 'Nowell',
#     'ownership': {'percentOwned': 0.026973742287961865},
#     'proTeamId': 16,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 1,
#     'droppable': True,
#     'eligibleSlots': [0, 5, 8, 11, 12, 13],
#     'firstName': 'Ja',
#     'fullName': 'Ja Morant',
#     'id': 4279888,
#     'lastName': 'Morant',
#     'ownership': {'percentOwned': 89.1029411764706},
#     'proTeamId': 29,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 3,
#     'droppable': True,
#     'eligibleSlots': [2, 6, 7, 8, 10, 11, 12, 13],
#     'firstName': 'Haywood',
#     'fullName': 'Haywood Highsmith',
#     'id': 4291678,
#     'lastName': 'Highsmith',
#     'ownership': {'percentOwned': 0.010295227916736118},
#     'proTeamId': 20,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 3,
#     'droppable': True,
#     'eligibleSlots': [2, 6, 7, 8, 10, 11, 12, 13],
#     'firstName': 'Dzanan',
#     'fullName': 'Dzanan Musa',
#     'id': 4348696,
#     'lastName': 'Musa',
#     'ownership': {'percentOwned': 0.06765435488140878},
#     'proTeamId': 17,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 3,
#     'droppable': True,
#     'eligibleSlots': [2, 6, 7, 8, 10, 11, 12, 13],
#     'firstName': 'Isaac',
#     'fullName': 'Isaac Bonga',
#     'id': 4348697,
#     'lastName': 'Bonga',
#     'ownership': {'percentOwned': 0.6358404172917218},
#     'proTeamId': 27,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [4, 9, 10, 11, 12, 13],
#     'firstName': 'Goga',
#     'fullName': 'Goga Bitadze',
#     'id': 4348700,
#     'lastName': 'Bitadze',
#     'ownership': {'percentOwned': 0.5380193824302586},
#     'proTeamId': 11,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 1,
#     'droppable': True,
#     'eligibleSlots': [0, 5, 8, 11, 12, 13],
#     'firstName': 'Issuf',
#     'fullName': 'Issuf Sanon',
#     'id': 4348701,
#     'lastName': 'Sanon',
#     'ownership': {'percentOwned': 0.009804978968320112},
#     'proTeamId': 27,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 5, 7, 8, 11, 12, 13],
#     'firstName': 'Vanja',
#     'fullName': 'Vanja Marinkovic',
#     'id': 4348710,
#     'lastName': 'Marinkovic',
#     'ownership': {'percentOwned': 0.026974006866110838},
#     'proTeamId': 23,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 5, 7, 8, 11, 12, 13],
#     'firstName': 'Anfernee',
#     'fullName': 'Anfernee Simons',
#     'id': 4351851,
#     'lastName': 'Simons',
#     'ownership': {'percentOwned': 0.6500509843909327},
#     'proTeamId': 22,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [4, 9, 10, 11, 12, 13],
#     'firstName': 'Mitchell',
#     'fullName': 'Mitchell Robinson',
#     'id': 4351852,
#     'lastName': 'Robinson',
#     'ownership': {'percentOwned': 78.70845651140102},
#     'proTeamId': 18,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Emanuel',
#     'fullName': 'Emanuel Terry',
#     'id': 4355392,
#     'lastName': 'Terry',
#     'ownership': {'percentOwned': 0.004902513518681028},
#     'proTeamId': 14,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 2, 5, 6, 7, 8, 10, 11, 12, 13],
#     'firstName': 'RJ',
#     'fullName': 'RJ Barrett',
#     'id': 4395625,
#     'lastName': 'Barrett',
#     'ownership': {'percentOwned': 92.13672616042236},
#     'proTeamId': 18,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 3,
#     'droppable': True,
#     'eligibleSlots': [1, 2, 5, 6, 7, 8, 10, 11, 12, 13],
#     'firstName': 'Cam',
#     'fullName': 'Cam Reddish',
#     'id': 4395627,
#     'lastName': 'Reddish',
#     'ownership': {'percentOwned': 10.609062377402903},
#     'proTeamId': 1,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Zion',
#     'fullName': 'Zion Williamson',
#     'id': 4395628,
#     'lastName': 'Williamson',
#     'ownership': {'percentOwned': 92.73316373297257},
#     'proTeamId': 3,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 1,
#     'droppable': True,
#     'eligibleSlots': [0, 5, 8, 11, 12, 13],
#     'firstName': 'Coby',
#     'fullName': 'Coby White',
#     'id': 4395651,
#     'lastName': 'White',
#     'ownership': {'percentOwned': 29.599497839828558},
#     'proTeamId': 4,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 3,
#     'droppable': True,
#     'eligibleSlots': [2, 6, 7, 8, 10, 11, 12, 13],
#     'firstName': 'Nassir',
#     'fullName': 'Nassir Little',
#     'id': 4395652,
#     'lastName': 'Little',
#     'ownership': {'percentOwned': 0.4104812488046021},
#     'proTeamId': 22,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 3,
#     'droppable': True,
#     'eligibleSlots': [1, 2, 5, 6, 7, 8, 10, 11, 12, 13],
#     'firstName': 'Keldon',
#     'fullName': 'Keldon Johnson',
#     'id': 4395723,
#     'lastName': 'Johnson',
#     'ownership': {'percentOwned': 0.41097771500313873},
#     'proTeamId': 24,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 5, 7, 8, 11, 12, 13],
#     'firstName': 'Tyler',
#     'fullName': 'Tyler Herro',
#     'id': 4395725,
#     'lastName': 'Herro',
#     'ownership': {'percentOwned': 46.833469011446},
#     'proTeamId': 14,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 1,
#     'droppable': True,
#     'eligibleSlots': [0, 5, 8, 11, 12, 13],
#     'firstName': 'Darius',
#     'fullName': 'Darius Garland',
#     'id': 4396907,
#     'lastName': 'Garland',
#     'ownership': {'percentOwned': 13.92828419545303},
#     'proTeamId': 5,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 2, 5, 6, 7, 8, 10, 11, 12, 13],
#     'firstName': 'Talen',
#     'fullName': 'Talen Horton-Tucker',
#     'id': 4396991,
#     'lastName': 'Horton-Tucker',
#     'ownership': {'percentOwned': 0.09367153170119272},
#     'proTeamId': 13,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 5, 7, 8, 11, 12, 13],
#     'firstName': 'Romeo',
#     'fullName': 'Romeo Langford',
#     'id': 4397008,
#     'lastName': 'Langford',
#     'ownership': {'percentOwned': 0.620889549340121},
#     'proTeamId': 2,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 5, 7, 8, 11, 12, 13],
#     'firstName': 'Luguentz',
#     'fullName': 'Luguentz Dort',
#     'id': 4397020,
#     'lastName': 'Dort',
#     'ownership': {'percentOwned': 0.026046188574405278},
#     'proTeamId': 25,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [4, 9, 10, 11, 12, 13],
#     'firstName': 'Jaxson',
#     'fullName': 'Jaxson Hayes',
#     'id': 4397077,
#     'lastName': 'Hayes',
#     'ownership': {'percentOwned': 8.021558213551858},
#     'proTeamId': 3,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 5,
#     'droppable': True,
#     'eligibleSlots': [4, 9, 10, 11, 12, 13],
#     'firstName': 'Bol',
#     'fullName': 'Bol Bol',
#     'id': 4397102,
#     'lastName': 'Bol',
#     'ownership': {'percentOwned': 1.384877180421446},
#     'proTeamId': 7,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 5, 7, 8, 11, 12, 13],
#     'firstName': 'Kevin',
#     'fullName': 'Kevin Porter Jr.',
#     'id': 4397140,
#     'lastName': 'Porter Jr.',
#     'ownership': {'percentOwned': 0.7037694578768232},
#     'proTeamId': 5,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Ignas',
#     'fullName': 'Ignas Brazdeikis',
#     'id': 4397205,
#     'lastName': 'Brazdeikis',
#     'ownership': {'percentOwned': 0.08827943383456434},
#     'proTeamId': 18,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Alen',
#     'fullName': 'Alen Smailagic',
#     'id': 4401415,
#     'lastName': 'Smailagic',
#     'ownership': {'percentOwned': 0.02795460564388775},
#     'proTeamId': 9,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Luka',
#     'fullName': 'Luka Samanic',
#     'id': 4423309,
#     'lastName': 'Samanic',
#     'ownership': {'percentOwned': 0.31191454718443173},
#     'proTeamId': 24,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 4,
#     'droppable': True,
#     'eligibleSlots': [3, 6, 8, 9, 10, 11, 12, 13],
#     'firstName': 'Sekou',
#     'fullName': 'Sekou Doumbouya',
#     'id': 4423314,
#     'lastName': 'Doumbouya',
#     'ownership': {'percentOwned': 0.5154462214506059},
#     'proTeamId': 8,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 3,
#     'droppable': True,
#     'eligibleSlots': [2, 6, 7, 8, 10, 11, 12, 13],
#     'firstName': 'Darius',
#     'fullName': 'Darius Bazley',
#     'id': 4423545,
#     'lastName': 'Bazley',
#     'ownership': {'percentOwned': 0.3692932423750509},
#     'proTeamId': 25,
#     'universeId': 2}},
#   {'player': {'defaultPositionId': 3,
#     'droppable': True,
#     'eligibleSlots': [2, 6, 7, 8, 10, 11, 12, 13],
#     'firstName': 'Deividas',
#     'fullName': 'Deividas Sirvydis',
#     'id': 4423883,
#     'lastName': 'Sirvydis',
#     'ownership': {'percentOwned': 0.02010799464440728},
#     'proTeamId': 8,
#     'universeId': 1}},
#   {'player': {'defaultPositionId': 2,
#     'droppable': True,
#     'eligibleSlots': [1, 5, 7, 8, 11, 12, 13],
#     'firstName': 'Marcos',
#     'fullName': 'Marcos Louzada Silva',
#     'id': 4423885,
#     'lastName': 'Louzada Silva',
#     'ownership': {'percentOwned': 0.039234341819394516},
#     'proTeamId': 3,
#     'universeId': 2}}]}

# %%
params = {
            'view': 'mDraftDetail',
        }

# %%
drafts = requests.get(f'{ENDPOINT}/seasons/{SEASON_ID}/segments/0/leagues/{LEAGUE_ID}', cookies=auths, params=params)

# %%
drafts.json()
# Out:
# {'draftDetail': {'completeDate': 1571713355535,
#   'drafted': True,
#   'inProgress': False,
#   'picks': [{'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 1,
#     'keeper': False,
#     'lineupSlotId': 1,
#     'memberId': '{5AF1DAE9-974E-4B12-864A-A2677B8EB690}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 1,
#     'playerId': 3992,
#     'reservedForKeeper': False,
#     'roundId': 1,
#     'roundPickNumber': 1,
#     'teamId': 2,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 2,
#     'keeper': False,
#     'lineupSlotId': 3,
#     'memberId': '{073D2BB1-1612-4E20-8066-303B069EAAFF}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 2,
#     'playerId': 3032977,
#     'reservedForKeeper': False,
#     'roundId': 1,
#     'roundPickNumber': 2,
#     'teamId': 5,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 3,
#     'keeper': False,
#     'lineupSlotId': 3,
#     'memberId': '{335F7A9A-4E5B-4E2C-B35A-CC9AA019E44C}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 3,
#     'playerId': 6583,
#     'reservedForKeeper': False,
#     'roundId': 1,
#     'roundPickNumber': 3,
#     'teamId': 1,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 4,
#     'keeper': False,
#     'lineupSlotId': 4,
#     'memberId': '{36067DE1-1BAD-475C-867D-E11BADF75C48}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 4,
#     'playerId': 3112335,
#     'reservedForKeeper': False,
#     'roundId': 1,
#     'roundPickNumber': 4,
#     'teamId': 10,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 3,
#     'bidAmount': 0,
#     'id': 5,
#     'keeper': False,
#     'lineupSlotId': 4,
#     'nominatingTeamId': 0,
#     'overallPickNumber': 5,
#     'playerId': 3136195,
#     'reservedForKeeper': False,
#     'roundId': 1,
#     'roundPickNumber': 5,
#     'teamId': 3,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 6,
#     'keeper': False,
#     'lineupSlotId': 0,
#     'memberId': '{BFDE2ADA-6AAA-4575-AD6C-4AF34A6B99D5}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 6,
#     'playerId': 3975,
#     'reservedForKeeper': False,
#     'roundId': 1,
#     'roundPickNumber': 6,
#     'teamId': 7,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 7,
#     'keeper': False,
#     'lineupSlotId': 0,
#     'memberId': '{DD012212-1A35-417E-9883-4B1E44BDF89C}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 7,
#     'playerId': 3907387,
#     'reservedForKeeper': False,
#     'roundId': 1,
#     'roundPickNumber': 7,
#     'teamId': 4,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 8,
#     'keeper': False,
#     'lineupSlotId': 2,
#     'memberId': '{20BEC7B8-923B-4B53-BEC7-B8923B8B534F}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 8,
#     'playerId': 1966,
#     'reservedForKeeper': False,
#     'roundId': 1,
#     'roundPickNumber': 8,
#     'teamId': 6,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 9,
#     'keeper': False,
#     'lineupSlotId': 4,
#     'memberId': '{F9FBE5BD-6546-4D97-907D-314EBCA8A0A9}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 9,
#     'playerId': 3059318,
#     'reservedForKeeper': False,
#     'roundId': 1,
#     'roundPickNumber': 9,
#     'teamId': 8,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 10,
#     'keeper': False,
#     'lineupSlotId': 1,
#     'memberId': '{05D164B9-F2F4-4FCA-97CF-1A8C0D02200F}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 10,
#     'playerId': 6580,
#     'reservedForKeeper': False,
#     'roundId': 1,
#     'roundPickNumber': 10,
#     'teamId': 9,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 11,
#     'keeper': False,
#     'lineupSlotId': 0,
#     'memberId': '{05D164B9-F2F4-4FCA-97CF-1A8C0D02200F}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 11,
#     'playerId': 6606,
#     'reservedForKeeper': False,
#     'roundId': 2,
#     'roundPickNumber': 1,
#     'teamId': 9,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 12,
#     'keeper': False,
#     'lineupSlotId': 1,
#     'memberId': '{F9FBE5BD-6546-4D97-907D-314EBCA8A0A9}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 12,
#     'playerId': 6430,
#     'reservedForKeeper': False,
#     'roundId': 2,
#     'roundPickNumber': 2,
#     'teamId': 8,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 13,
#     'keeper': False,
#     'lineupSlotId': 4,
#     'memberId': '{20BEC7B8-923B-4B53-BEC7-B8923B8B534F}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 13,
#     'playerId': 3032976,
#     'reservedForKeeper': False,
#     'roundId': 2,
#     'roundPickNumber': 3,
#     'teamId': 6,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 14,
#     'keeper': False,
#     'lineupSlotId': 3,
#     'memberId': '{DD012212-1A35-417E-9883-4B1E44BDF89C}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 14,
#     'playerId': 3149673,
#     'reservedForKeeper': False,
#     'roundId': 2,
#     'roundPickNumber': 4,
#     'teamId': 4,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 15,
#     'keeper': False,
#     'lineupSlotId': 1,
#     'memberId': '{BFDE2ADA-6AAA-4575-AD6C-4AF34A6B99D5}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 15,
#     'playerId': 3945274,
#     'reservedForKeeper': False,
#     'roundId': 2,
#     'roundPickNumber': 5,
#     'teamId': 7,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 16,
#     'keeper': False,
#     'lineupSlotId': 0,
#     'memberId': '{07B59F4A-A159-414C-B59F-4AA159214C3F}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 16,
#     'playerId': 6442,
#     'reservedForKeeper': False,
#     'roundId': 2,
#     'roundPickNumber': 6,
#     'teamId': 3,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 17,
#     'keeper': False,
#     'lineupSlotId': 0,
#     'memberId': '{36067DE1-1BAD-475C-867D-E11BADF75C48}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 17,
#     'playerId': 3468,
#     'reservedForKeeper': False,
#     'roundId': 2,
#     'roundPickNumber': 7,
#     'teamId': 10,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 18,
#     'keeper': False,
#     'lineupSlotId': 2,
#     'memberId': '{335F7A9A-4E5B-4E2C-B35A-CC9AA019E44C}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 18,
#     'playerId': 6450,
#     'reservedForKeeper': False,
#     'roundId': 2,
#     'roundPickNumber': 8,
#     'teamId': 1,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 19,
#     'keeper': False,
#     'lineupSlotId': 4,
#     'memberId': '{073D2BB1-1612-4E20-8066-303B069EAAFF}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 19,
#     'playerId': 6585,
#     'reservedForKeeper': False,
#     'roundId': 2,
#     'roundPickNumber': 9,
#     'teamId': 5,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 20,
#     'keeper': False,
#     'lineupSlotId': 4,
#     'memberId': '{5AF1DAE9-974E-4B12-864A-A2677B8EB690}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 20,
#     'playerId': 6478,
#     'reservedForKeeper': False,
#     'roundId': 2,
#     'roundPickNumber': 10,
#     'teamId': 2,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 21,
#     'keeper': False,
#     'lineupSlotId': 0,
#     'memberId': '{5AF1DAE9-974E-4B12-864A-A2677B8EB690}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 21,
#     'playerId': 3995,
#     'reservedForKeeper': False,
#     'roundId': 3,
#     'roundPickNumber': 1,
#     'teamId': 2,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 22,
#     'keeper': False,
#     'lineupSlotId': 6,
#     'memberId': '{073D2BB1-1612-4E20-8066-303B069EAAFF}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 22,
#     'playerId': 3908845,
#     'reservedForKeeper': False,
#     'roundId': 3,
#     'roundPickNumber': 2,
#     'teamId': 5,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 23,
#     'keeper': False,
#     'lineupSlotId': 0,
#     'memberId': '{335F7A9A-4E5B-4E2C-B35A-CC9AA019E44C}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 23,
#     'playerId': 6479,
#     'reservedForKeeper': False,
#     'roundId': 3,
#     'roundPickNumber': 3,
#     'teamId': 1,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 24,
#     'keeper': False,
#     'lineupSlotId': 2,
#     'memberId': '{36067DE1-1BAD-475C-867D-E11BADF75C48}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 24,
#     'playerId': 4251,
#     'reservedForKeeper': False,
#     'roundId': 3,
#     'roundPickNumber': 4,
#     'teamId': 10,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 25,
#     'keeper': False,
#     'lineupSlotId': 3,
#     'memberId': '{07B59F4A-A159-414C-B59F-4AA159214C3F}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 25,
#     'playerId': 3989,
#     'reservedForKeeper': False,
#     'roundId': 3,
#     'roundPickNumber': 5,
#     'teamId': 3,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 26,
#     'keeper': False,
#     'lineupSlotId': 4,
#     'memberId': '{BFDE2ADA-6AAA-4575-AD6C-4AF34A6B99D5}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 26,
#     'playerId': 4278129,
#     'reservedForKeeper': False,
#     'roundId': 3,
#     'roundPickNumber': 6,
#     'teamId': 7,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 27,
#     'keeper': False,
#     'lineupSlotId': 1,
#     'memberId': '{DD012212-1A35-417E-9883-4B1E44BDF89C}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 27,
#     'playerId': 3908809,
#     'reservedForKeeper': False,
#     'roundId': 3,
#     'roundPickNumber': 7,
#     'teamId': 4,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 28,
#     'keeper': False,
#     'lineupSlotId': 0,
#     'memberId': '{20BEC7B8-923B-4B53-BEC7-B8923B8B534F}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 28,
#     'playerId': 4066259,
#     'reservedForKeeper': False,
#     'roundId': 3,
#     'roundPickNumber': 8,
#     'teamId': 6,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 29,
#     'keeper': False,
#     'lineupSlotId': 2,
#     'memberId': '{F9FBE5BD-6546-4D97-907D-314EBCA8A0A9}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 29,
#     'playerId': 4065648,
#     'reservedForKeeper': False,
#     'roundId': 3,
#     'roundPickNumber': 9,
#     'teamId': 8,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 30,
#     'keeper': False,
#     'lineupSlotId': 5,
#     'memberId': '{05D164B9-F2F4-4FCA-97CF-1A8C0D02200F}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 30,
#     'playerId': 4277905,
#     'reservedForKeeper': False,
#     'roundId': 3,
#     'roundPickNumber': 10,
#     'teamId': 9,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 31,
#     'keeper': False,
#     'lineupSlotId': 11,
#     'memberId': '{05D164B9-F2F4-4FCA-97CF-1A8C0D02200F}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 31,
#     'playerId': 3064440,
#     'reservedForKeeper': False,
#     'roundId': 4,
#     'roundPickNumber': 1,
#     'teamId': 9,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 32,
#     'keeper': False,
#     'lineupSlotId': 3,
#     'memberId': '{F9FBE5BD-6546-4D97-907D-314EBCA8A0A9}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 32,
#     'playerId': 3102531,
#     'reservedForKeeper': False,
#     'roundId': 4,
#     'roundPickNumber': 2,
#     'teamId': 8,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 33,
#     'keeper': False,
#     'lineupSlotId': 1,
#     'memberId': '{20BEC7B8-923B-4B53-BEC7-B8923B8B534F}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 33,
#     'playerId': 3978,
#     'reservedForKeeper': False,
#     'roundId': 4,
#     'roundPickNumber': 3,
#     'teamId': 6,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 34,
#     'keeper': False,
#     'lineupSlotId': 4,
#     'memberId': '{DD012212-1A35-417E-9883-4B1E44BDF89C}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 34,
#     'playerId': 3102529,
#     'reservedForKeeper': False,
#     'roundId': 4,
#     'roundPickNumber': 4,
#     'teamId': 4,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 35,
#     'keeper': False,
#     'lineupSlotId': 3,
#     'memberId': '{BFDE2ADA-6AAA-4575-AD6C-4AF34A6B99D5}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 35,
#     'playerId': 2991055,
#     'reservedForKeeper': False,
#     'roundId': 4,
#     'roundPickNumber': 5,
#     'teamId': 7,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 36,
#     'keeper': False,
#     'lineupSlotId': 1,
#     'memberId': '{07B59F4A-A159-414C-B59F-4AA159214C3F}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 36,
#     'playerId': 3136193,
#     'reservedForKeeper': False,
#     'roundId': 4,
#     'roundPickNumber': 6,
#     'teamId': 3,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 37,
#     'keeper': False,
#     'lineupSlotId': 3,
#     'memberId': '{36067DE1-1BAD-475C-867D-E11BADF75C48}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 37,
#     'playerId': 4066336,
#     'reservedForKeeper': False,
#     'roundId': 4,
#     'roundPickNumber': 7,
#     'teamId': 10,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 38,
#     'keeper': False,
#     'lineupSlotId': 1,
#     'memberId': '{335F7A9A-4E5B-4E2C-B35A-CC9AA019E44C}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 38,
#     'playerId': 3136776,
#     'reservedForKeeper': False,
#     'roundId': 4,
#     'roundPickNumber': 8,
#     'teamId': 1,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 39,
#     'keeper': False,
#     'lineupSlotId': 1,
#     'memberId': '{073D2BB1-1612-4E20-8066-303B069EAAFF}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 39,
#     'playerId': 2990984,
#     'reservedForKeeper': False,
#     'roundId': 4,
#     'roundPickNumber': 9,
#     'teamId': 5,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 40,
#     'keeper': False,
#     'lineupSlotId': 3,
#     'memberId': '{5AF1DAE9-974E-4B12-864A-A2677B8EB690}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 40,
#     'playerId': 2983,
#     'reservedForKeeper': False,
#     'roundId': 4,
#     'roundPickNumber': 10,
#     'teamId': 2,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 41,
#     'keeper': False,
#     'lineupSlotId': 6,
#     'memberId': '{5AF1DAE9-974E-4B12-864A-A2677B8EB690}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 41,
#     'playerId': 6589,
#     'reservedForKeeper': False,
#     'roundId': 5,
#     'roundPickNumber': 1,
#     'teamId': 2,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 42,
#     'keeper': False,
#     'lineupSlotId': 0,
#     'memberId': '{073D2BB1-1612-4E20-8066-303B069EAAFF}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 42,
#     'playerId': 3936299,
#     'reservedForKeeper': False,
#     'roundId': 5,
#     'roundPickNumber': 2,
#     'teamId': 5,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 43,
#     'keeper': False,
#     'lineupSlotId': 4,
#     'memberId': '{335F7A9A-4E5B-4E2C-B35A-CC9AA019E44C}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 43,
#     'playerId': 3449,
#     'reservedForKeeper': False,
#     'roundId': 5,
#     'roundPickNumber': 3,
#     'teamId': 1,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 44,
#     'keeper': False,
#     'lineupSlotId': 6,
#     'memberId': '{36067DE1-1BAD-475C-867D-E11BADF75C48}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 44,
#     'playerId': 6440,
#     'reservedForKeeper': False,
#     'roundId': 5,
#     'roundPickNumber': 4,
#     'teamId': 10,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 45,
#     'keeper': False,
#     'lineupSlotId': 2,
#     'memberId': '{07B59F4A-A159-414C-B59F-4AA159214C3F}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 45,
#     'playerId': 6609,
#     'reservedForKeeper': False,
#     'roundId': 5,
#     'roundPickNumber': 5,
#     'teamId': 3,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 46,
#     'keeper': False,
#     'lineupSlotId': 2,
#     'memberId': '{BFDE2ADA-6AAA-4575-AD6C-4AF34A6B99D5}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 46,
#     'playerId': 2594922,
#     'reservedForKeeper': False,
#     'roundId': 5,
#     'roundPickNumber': 6,
#     'teamId': 7,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 47,
#     'keeper': False,
#     'lineupSlotId': 2,
#     'memberId': '{DD012212-1A35-417E-9883-4B1E44BDF89C}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 47,
#     'playerId': 3134907,
#     'reservedForKeeper': False,
#     'roundId': 5,
#     'roundPickNumber': 7,
#     'teamId': 4,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 48,
#     'keeper': False,
#     'lineupSlotId': 11,
#     'memberId': '{20BEC7B8-923B-4B53-BEC7-B8923B8B534F}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 48,
#     'playerId': 6477,
#     'reservedForKeeper': False,
#     'roundId': 5,
#     'roundPickNumber': 8,
#     'teamId': 6,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 49,
#     'keeper': False,
#     'lineupSlotId': 6,
#     'memberId': '{F9FBE5BD-6546-4D97-907D-314EBCA8A0A9}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 49,
#     'playerId': 3064514,
#     'reservedForKeeper': False,
#     'roundId': 5,
#     'roundPickNumber': 9,
#     'teamId': 8,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 50,
#     'keeper': False,
#     'lineupSlotId': 3,
#     'memberId': '{05D164B9-F2F4-4FCA-97CF-1A8C0D02200F}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 50,
#     'playerId': 4277848,
#     'reservedForKeeper': False,
#     'roundId': 5,
#     'roundPickNumber': 10,
#     'teamId': 9,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 51,
#     'keeper': False,
#     'lineupSlotId': 4,
#     'memberId': '{05D164B9-F2F4-4FCA-97CF-1A8C0D02200F}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 51,
#     'playerId': 3934723,
#     'reservedForKeeper': False,
#     'roundId': 6,
#     'roundPickNumber': 1,
#     'teamId': 9,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 52,
#     'keeper': False,
#     'lineupSlotId': 5,
#     'memberId': '{F9FBE5BD-6546-4D97-907D-314EBCA8A0A9}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 52,
#     'playerId': 2490149,
#     'reservedForKeeper': False,
#     'roundId': 6,
#     'roundPickNumber': 2,
#     'teamId': 8,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 53,
#     'keeper': False,
#     'lineupSlotId': 5,
#     'memberId': '{20BEC7B8-923B-4B53-BEC7-B8923B8B534F}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 53,
#     'playerId': 2566769,
#     'reservedForKeeper': False,
#     'roundId': 6,
#     'roundPickNumber': 3,
#     'teamId': 6,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 54,
#     'keeper': False,
#     'lineupSlotId': 6,
#     'memberId': '{DD012212-1A35-417E-9883-4B1E44BDF89C}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 54,
#     'playerId': 4257,
#     'reservedForKeeper': False,
#     'roundId': 6,
#     'roundPickNumber': 4,
#     'teamId': 4,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 55,
#     'keeper': False,
#     'lineupSlotId': 5,
#     'memberId': '{BFDE2ADA-6AAA-4575-AD6C-4AF34A6B99D5}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 55,
#     'playerId': 3074752,
#     'reservedForKeeper': False,
#     'roundId': 6,
#     'roundPickNumber': 5,
#     'teamId': 7,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 56,
#     'keeper': False,
#     'lineupSlotId': 5,
#     'memberId': '{07B59F4A-A159-414C-B59F-4AA159214C3F}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 56,
#     'playerId': 3195,
#     'reservedForKeeper': False,
#     'roundId': 6,
#     'roundPickNumber': 6,
#     'teamId': 3,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 57,
#     'keeper': False,
#     'lineupSlotId': 5,
#     'memberId': '{36067DE1-1BAD-475C-867D-E11BADF75C48}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 57,
#     'playerId': 4066421,
#     'reservedForKeeper': False,
#     'roundId': 6,
#     'roundPickNumber': 7,
#     'teamId': 10,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 58,
#     'keeper': False,
#     'lineupSlotId': 5,
#     'memberId': '{335F7A9A-4E5B-4E2C-B35A-CC9AA019E44C}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 58,
#     'playerId': 4238,
#     'reservedForKeeper': False,
#     'roundId': 6,
#     'roundPickNumber': 8,
#     'teamId': 1,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 59,
#     'keeper': False,
#     'lineupSlotId': 11,
#     'memberId': '{073D2BB1-1612-4E20-8066-303B069EAAFF}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 59,
#     'playerId': 3155942,
#     'reservedForKeeper': False,
#     'roundId': 6,
#     'roundPickNumber': 9,
#     'teamId': 5,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 60,
#     'keeper': False,
#     'lineupSlotId': 11,
#     'memberId': '{5AF1DAE9-974E-4B12-864A-A2677B8EB690}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 60,
#     'playerId': 4066261,
#     'reservedForKeeper': False,
#     'roundId': 6,
#     'roundPickNumber': 10,
#     'teamId': 2,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 61,
#     'keeper': False,
#     'lineupSlotId': 5,
#     'memberId': '{5AF1DAE9-974E-4B12-864A-A2677B8EB690}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 61,
#     'playerId': 2779,
#     'reservedForKeeper': False,
#     'roundId': 7,
#     'roundPickNumber': 1,
#     'teamId': 2,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 62,
#     'keeper': False,
#     'lineupSlotId': 5,
#     'memberId': '{073D2BB1-1612-4E20-8066-303B069EAAFF}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 62,
#     'playerId': 3012,
#     'reservedForKeeper': False,
#     'roundId': 7,
#     'roundPickNumber': 2,
#     'teamId': 5,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 63,
#     'keeper': False,
#     'lineupSlotId': 6,
#     'memberId': '{335F7A9A-4E5B-4E2C-B35A-CC9AA019E44C}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 63,
#     'playerId': 3428,
#     'reservedForKeeper': False,
#     'roundId': 7,
#     'roundPickNumber': 3,
#     'teamId': 1,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 64,
#     'keeper': False,
#     'lineupSlotId': 1,
#     'memberId': '{36067DE1-1BAD-475C-867D-E11BADF75C48}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 64,
#     'playerId': 2799,
#     'reservedForKeeper': False,
#     'roundId': 7,
#     'roundPickNumber': 4,
#     'teamId': 10,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 65,
#     'keeper': False,
#     'lineupSlotId': 11,
#     'memberId': '{07B59F4A-A159-414C-B59F-4AA159214C3F}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 65,
#     'playerId': 6447,
#     'reservedForKeeper': False,
#     'roundId': 7,
#     'roundPickNumber': 5,
#     'teamId': 3,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 66,
#     'keeper': False,
#     'lineupSlotId': 6,
#     'memberId': '{BFDE2ADA-6AAA-4575-AD6C-4AF34A6B99D5}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 66,
#     'playerId': 4395628,
#     'reservedForKeeper': False,
#     'roundId': 7,
#     'roundPickNumber': 6,
#     'teamId': 7,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 67,
#     'keeper': False,
#     'lineupSlotId': 5,
#     'memberId': '{DD012212-1A35-417E-9883-4B1E44BDF89C}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 67,
#     'playerId': 4395625,
#     'reservedForKeeper': False,
#     'roundId': 7,
#     'roundPickNumber': 7,
#     'teamId': 4,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 68,
#     'keeper': False,
#     'lineupSlotId': 11,
#     'memberId': '{20BEC7B8-923B-4B53-BEC7-B8923B8B534F}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 68,
#     'playerId': 4279888,
#     'reservedForKeeper': False,
#     'roundId': 7,
#     'roundPickNumber': 8,
#     'teamId': 6,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 69,
#     'keeper': False,
#     'lineupSlotId': 11,
#     'memberId': '{F9FBE5BD-6546-4D97-907D-314EBCA8A0A9}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 69,
#     'playerId': 4277961,
#     'reservedForKeeper': False,
#     'roundId': 7,
#     'roundPickNumber': 9,
#     'teamId': 8,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 70,
#     'keeper': False,
#     'lineupSlotId': 2,
#     'memberId': '{05D164B9-F2F4-4FCA-97CF-1A8C0D02200F}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 70,
#     'playerId': 3593,
#     'reservedForKeeper': False,
#     'roundId': 7,
#     'roundPickNumber': 10,
#     'teamId': 9,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 71,
#     'keeper': False,
#     'lineupSlotId': 6,
#     'memberId': '{05D164B9-F2F4-4FCA-97CF-1A8C0D02200F}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 71,
#     'playerId': 3064290,
#     'reservedForKeeper': False,
#     'roundId': 8,
#     'roundPickNumber': 1,
#     'teamId': 9,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 72,
#     'keeper': False,
#     'lineupSlotId': 11,
#     'memberId': '{F9FBE5BD-6546-4D97-907D-314EBCA8A0A9}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 72,
#     'playerId': 2991235,
#     'reservedForKeeper': False,
#     'roundId': 8,
#     'roundPickNumber': 2,
#     'teamId': 8,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 3,
#     'bidAmount': 0,
#     'id': 73,
#     'keeper': False,
#     'lineupSlotId': 11,
#     'nominatingTeamId': 0,
#     'overallPickNumber': 73,
#     'playerId': 4351852,
#     'reservedForKeeper': False,
#     'roundId': 8,
#     'roundPickNumber': 3,
#     'teamId': 6,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 74,
#     'keeper': False,
#     'lineupSlotId': 11,
#     'memberId': '{DD012212-1A35-417E-9883-4B1E44BDF89C}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 74,
#     'playerId': 3059319,
#     'reservedForKeeper': False,
#     'roundId': 8,
#     'roundPickNumber': 4,
#     'teamId': 4,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 75,
#     'keeper': False,
#     'lineupSlotId': 11,
#     'memberId': '{BFDE2ADA-6AAA-4575-AD6C-4AF34A6B99D5}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 75,
#     'playerId': 4262,
#     'reservedForKeeper': False,
#     'roundId': 8,
#     'roundPickNumber': 5,
#     'teamId': 7,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 76,
#     'keeper': False,
#     'lineupSlotId': 6,
#     'memberId': '{07B59F4A-A159-414C-B59F-4AA159214C3F}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 76,
#     'playerId': 2991043,
#     'reservedForKeeper': False,
#     'roundId': 8,
#     'roundPickNumber': 6,
#     'teamId': 3,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 77,
#     'keeper': False,
#     'lineupSlotId': 11,
#     'memberId': '{36067DE1-1BAD-475C-867D-E11BADF75C48}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 77,
#     'playerId': 3133628,
#     'reservedForKeeper': False,
#     'roundId': 8,
#     'roundPickNumber': 7,
#     'teamId': 10,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 78,
#     'keeper': False,
#     'lineupSlotId': 11,
#     'memberId': '{335F7A9A-4E5B-4E2C-B35A-CC9AA019E44C}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 78,
#     'playerId': 3442,
#     'reservedForKeeper': False,
#     'roundId': 8,
#     'roundPickNumber': 8,
#     'teamId': 1,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 79,
#     'keeper': False,
#     'lineupSlotId': 11,
#     'memberId': '{073D2BB1-1612-4E20-8066-303B069EAAFF}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 79,
#     'playerId': 3213,
#     'reservedForKeeper': False,
#     'roundId': 8,
#     'roundPickNumber': 9,
#     'teamId': 5,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 80,
#     'keeper': False,
#     'lineupSlotId': 2,
#     'memberId': '{5AF1DAE9-974E-4B12-864A-A2677B8EB690}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 80,
#     'playerId': 2490620,
#     'reservedForKeeper': False,
#     'roundId': 8,
#     'roundPickNumber': 10,
#     'teamId': 2,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 81,
#     'keeper': False,
#     'lineupSlotId': 11,
#     'memberId': '{5AF1DAE9-974E-4B12-864A-A2677B8EB690}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 81,
#     'playerId': 4011,
#     'reservedForKeeper': False,
#     'roundId': 9,
#     'roundPickNumber': 1,
#     'teamId': 2,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 82,
#     'keeper': False,
#     'lineupSlotId': 2,
#     'memberId': '{073D2BB1-1612-4E20-8066-303B069EAAFF}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 82,
#     'playerId': 6603,
#     'reservedForKeeper': False,
#     'roundId': 9,
#     'roundPickNumber': 2,
#     'teamId': 5,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 83,
#     'keeper': False,
#     'lineupSlotId': 11,
#     'memberId': '{335F7A9A-4E5B-4E2C-B35A-CC9AA019E44C}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 83,
#     'playerId': 2581190,
#     'reservedForKeeper': False,
#     'roundId': 9,
#     'roundPickNumber': 3,
#     'teamId': 1,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 84,
#     'keeper': False,
#     'lineupSlotId': 11,
#     'memberId': '{36067DE1-1BAD-475C-867D-E11BADF75C48}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 84,
#     'playerId': 3439,
#     'reservedForKeeper': False,
#     'roundId': 9,
#     'roundPickNumber': 4,
#     'teamId': 10,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 85,
#     'keeper': False,
#     'lineupSlotId': 11,
#     'memberId': '{07B59F4A-A159-414C-B59F-4AA159214C3F}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 85,
#     'playerId': 4277847,
#     'reservedForKeeper': False,
#     'roundId': 9,
#     'roundPickNumber': 5,
#     'teamId': 3,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 86,
#     'keeper': False,
#     'lineupSlotId': 11,
#     'memberId': '{BFDE2ADA-6AAA-4575-AD6C-4AF34A6B99D5}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 86,
#     'playerId': 4278073,
#     'reservedForKeeper': False,
#     'roundId': 9,
#     'roundPickNumber': 6,
#     'teamId': 7,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 87,
#     'keeper': False,
#     'lineupSlotId': 11,
#     'memberId': '{DD012212-1A35-417E-9883-4B1E44BDF89C}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 87,
#     'playerId': 4015,
#     'reservedForKeeper': False,
#     'roundId': 9,
#     'roundPickNumber': 7,
#     'teamId': 4,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 3,
#     'bidAmount': 0,
#     'id': 88,
#     'keeper': False,
#     'lineupSlotId': 3,
#     'nominatingTeamId': 0,
#     'overallPickNumber': 88,
#     'playerId': 3032978,
#     'reservedForKeeper': False,
#     'roundId': 9,
#     'roundPickNumber': 8,
#     'teamId': 6,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 89,
#     'keeper': False,
#     'lineupSlotId': 0,
#     'memberId': '{F9FBE5BD-6546-4D97-907D-314EBCA8A0A9}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 89,
#     'playerId': 3032979,
#     'reservedForKeeper': False,
#     'roundId': 9,
#     'roundPickNumber': 9,
#     'teamId': 8,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 90,
#     'keeper': False,
#     'lineupSlotId': 11,
#     'memberId': '{05D164B9-F2F4-4FCA-97CF-1A8C0D02200F}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 90,
#     'playerId': 3917376,
#     'reservedForKeeper': False,
#     'roundId': 9,
#     'roundPickNumber': 10,
#     'teamId': 9,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 91,
#     'keeper': False,
#     'lineupSlotId': 11,
#     'memberId': '{05D164B9-F2F4-4FCA-97CF-1A8C0D02200F}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 91,
#     'playerId': 2527963,
#     'reservedForKeeper': False,
#     'roundId': 10,
#     'roundPickNumber': 1,
#     'teamId': 9,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 92,
#     'keeper': False,
#     'lineupSlotId': 11,
#     'memberId': '{F9FBE5BD-6546-4D97-907D-314EBCA8A0A9}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 92,
#     'playerId': 4249,
#     'reservedForKeeper': False,
#     'roundId': 10,
#     'roundPickNumber': 2,
#     'teamId': 8,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 93,
#     'keeper': False,
#     'lineupSlotId': 6,
#     'memberId': '{20BEC7B8-923B-4B53-BEC7-B8923B8B534F}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 93,
#     'playerId': 2982334,
#     'reservedForKeeper': False,
#     'roundId': 10,
#     'roundPickNumber': 3,
#     'teamId': 6,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 94,
#     'keeper': False,
#     'lineupSlotId': 11,
#     'memberId': '{DD012212-1A35-417E-9883-4B1E44BDF89C}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 94,
#     'playerId': 4066328,
#     'reservedForKeeper': False,
#     'roundId': 10,
#     'roundPickNumber': 4,
#     'teamId': 4,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 95,
#     'keeper': False,
#     'lineupSlotId': 11,
#     'memberId': '{BFDE2ADA-6AAA-4575-AD6C-4AF34A6B99D5}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 95,
#     'playerId': 3907497,
#     'reservedForKeeper': False,
#     'roundId': 10,
#     'roundPickNumber': 5,
#     'teamId': 7,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 96,
#     'keeper': False,
#     'lineupSlotId': 11,
#     'memberId': '{07B59F4A-A159-414C-B59F-4AA159214C3F}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 96,
#     'playerId': 3913176,
#     'reservedForKeeper': False,
#     'roundId': 10,
#     'roundPickNumber': 6,
#     'teamId': 3,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 97,
#     'keeper': False,
#     'lineupSlotId': 11,
#     'memberId': '{36067DE1-1BAD-475C-867D-E11BADF75C48}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 97,
#     'playerId': 2528426,
#     'reservedForKeeper': False,
#     'roundId': 10,
#     'roundPickNumber': 7,
#     'teamId': 10,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 98,
#     'keeper': False,
#     'lineupSlotId': 11,
#     'memberId': '{335F7A9A-4E5B-4E2C-B35A-CC9AA019E44C}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 98,
#     'playerId': 4065732,
#     'reservedForKeeper': False,
#     'roundId': 10,
#     'roundPickNumber': 8,
#     'teamId': 1,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 99,
#     'keeper': False,
#     'lineupSlotId': 11,
#     'memberId': '{073D2BB1-1612-4E20-8066-303B069EAAFF}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 99,
#     'playerId': 2968436,
#     'reservedForKeeper': False,
#     'roundId': 10,
#     'roundPickNumber': 9,
#     'teamId': 5,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 100,
#     'keeper': False,
#     'lineupSlotId': 11,
#     'memberId': '{5AF1DAE9-974E-4B12-864A-A2677B8EB690}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 100,
#     'playerId': 4066383,
#     'reservedForKeeper': False,
#     'roundId': 10,
#     'roundPickNumber': 10,
#     'teamId': 2,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 101,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{5AF1DAE9-974E-4B12-864A-A2677B8EB690}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 101,
#     'playerId': 3448,
#     'reservedForKeeper': False,
#     'roundId': 11,
#     'roundPickNumber': 1,
#     'teamId': 2,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 102,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{073D2BB1-1612-4E20-8066-303B069EAAFF}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 102,
#     'playerId': 2580365,
#     'reservedForKeeper': False,
#     'roundId': 11,
#     'roundPickNumber': 2,
#     'teamId': 5,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 103,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{335F7A9A-4E5B-4E2C-B35A-CC9AA019E44C}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 103,
#     'playerId': 3135047,
#     'reservedForKeeper': False,
#     'roundId': 11,
#     'roundPickNumber': 3,
#     'teamId': 1,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 104,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{36067DE1-1BAD-475C-867D-E11BADF75C48}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 104,
#     'playerId': 2580782,
#     'reservedForKeeper': False,
#     'roundId': 11,
#     'roundPickNumber': 4,
#     'teamId': 10,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 105,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{07B59F4A-A159-414C-B59F-4AA159214C3F}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 105,
#     'playerId': 4066372,
#     'reservedForKeeper': False,
#     'roundId': 11,
#     'roundPickNumber': 5,
#     'teamId': 3,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 106,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{BFDE2ADA-6AAA-4575-AD6C-4AF34A6B99D5}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 106,
#     'playerId': 3133603,
#     'reservedForKeeper': False,
#     'roundId': 11,
#     'roundPickNumber': 6,
#     'teamId': 7,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 107,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{DD012212-1A35-417E-9883-4B1E44BDF89C}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 107,
#     'playerId': 3015,
#     'reservedForKeeper': False,
#     'roundId': 11,
#     'roundPickNumber': 7,
#     'teamId': 4,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 3,
#     'bidAmount': 0,
#     'id': 108,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'nominatingTeamId': 0,
#     'overallPickNumber': 108,
#     'playerId': 2531367,
#     'reservedForKeeper': False,
#     'roundId': 11,
#     'roundPickNumber': 8,
#     'teamId': 6,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 109,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{F9FBE5BD-6546-4D97-907D-314EBCA8A0A9}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 109,
#     'playerId': 3456,
#     'reservedForKeeper': False,
#     'roundId': 11,
#     'roundPickNumber': 9,
#     'teamId': 8,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 110,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{05D164B9-F2F4-4FCA-97CF-1A8C0D02200F}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 110,
#     'playerId': 4277811,
#     'reservedForKeeper': False,
#     'roundId': 11,
#     'roundPickNumber': 10,
#     'teamId': 9,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 111,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{05D164B9-F2F4-4FCA-97CF-1A8C0D02200F}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 111,
#     'playerId': 4278075,
#     'reservedForKeeper': False,
#     'roundId': 12,
#     'roundPickNumber': 1,
#     'teamId': 9,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 112,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{F9FBE5BD-6546-4D97-907D-314EBCA8A0A9}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 112,
#     'playerId': 4396907,
#     'reservedForKeeper': False,
#     'roundId': 12,
#     'roundPickNumber': 2,
#     'teamId': 8,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 3,
#     'bidAmount': 0,
#     'id': 113,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'nominatingTeamId': 0,
#     'overallPickNumber': 113,
#     'playerId': 3906665,
#     'reservedForKeeper': False,
#     'roundId': 12,
#     'roundPickNumber': 3,
#     'teamId': 6,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 114,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{DD012212-1A35-417E-9883-4B1E44BDF89C}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 114,
#     'playerId': 6619,
#     'reservedForKeeper': False,
#     'roundId': 12,
#     'roundPickNumber': 4,
#     'teamId': 4,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 115,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{BFDE2ADA-6AAA-4575-AD6C-4AF34A6B99D5}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 115,
#     'playerId': 6588,
#     'reservedForKeeper': False,
#     'roundId': 12,
#     'roundPickNumber': 5,
#     'teamId': 7,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 116,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{07B59F4A-A159-414C-B59F-4AA159214C3F}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 116,
#     'playerId': 4065697,
#     'reservedForKeeper': False,
#     'roundId': 12,
#     'roundPickNumber': 6,
#     'teamId': 3,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 117,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{36067DE1-1BAD-475C-867D-E11BADF75C48}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 117,
#     'playerId': 2990992,
#     'reservedForKeeper': False,
#     'roundId': 12,
#     'roundPickNumber': 7,
#     'teamId': 10,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 118,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{335F7A9A-4E5B-4E2C-B35A-CC9AA019E44C}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 118,
#     'playerId': 4065654,
#     'reservedForKeeper': False,
#     'roundId': 12,
#     'roundPickNumber': 8,
#     'teamId': 1,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 119,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{073D2BB1-1612-4E20-8066-303B069EAAFF}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 119,
#     'playerId': 2528794,
#     'reservedForKeeper': False,
#     'roundId': 12,
#     'roundPickNumber': 9,
#     'teamId': 5,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 120,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{5AF1DAE9-974E-4B12-864A-A2677B8EB690}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 120,
#     'playerId': 3206,
#     'reservedForKeeper': False,
#     'roundId': 12,
#     'roundPickNumber': 10,
#     'teamId': 2,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 121,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{5AF1DAE9-974E-4B12-864A-A2677B8EB690}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 121,
#     'playerId': 3064447,
#     'reservedForKeeper': False,
#     'roundId': 13,
#     'roundPickNumber': 1,
#     'teamId': 2,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 122,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{073D2BB1-1612-4E20-8066-303B069EAAFF}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 122,
#     'playerId': 3064482,
#     'reservedForKeeper': False,
#     'roundId': 13,
#     'roundPickNumber': 2,
#     'teamId': 5,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 123,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{335F7A9A-4E5B-4E2C-B35A-CC9AA019E44C}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 123,
#     'playerId': 2991282,
#     'reservedForKeeper': False,
#     'roundId': 13,
#     'roundPickNumber': 3,
#     'teamId': 1,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 124,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{36067DE1-1BAD-475C-867D-E11BADF75C48}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 124,
#     'playerId': 3005,
#     'reservedForKeeper': False,
#     'roundId': 13,
#     'roundPickNumber': 4,
#     'teamId': 10,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 125,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{07B59F4A-A159-414C-B59F-4AA159214C3F}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 125,
#     'playerId': 6578,
#     'reservedForKeeper': False,
#     'roundId': 13,
#     'roundPickNumber': 5,
#     'teamId': 3,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 126,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{BFDE2ADA-6AAA-4575-AD6C-4AF34A6B99D5}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 126,
#     'playerId': 2999547,
#     'reservedForKeeper': False,
#     'roundId': 13,
#     'roundPickNumber': 6,
#     'teamId': 7,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 127,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{DD012212-1A35-417E-9883-4B1E44BDF89C}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 127,
#     'playerId': 3423,
#     'reservedForKeeper': False,
#     'roundId': 13,
#     'roundPickNumber': 7,
#     'teamId': 4,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 3,
#     'bidAmount': 0,
#     'id': 128,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'nominatingTeamId': 0,
#     'overallPickNumber': 128,
#     'playerId': 4248,
#     'reservedForKeeper': False,
#     'roundId': 13,
#     'roundPickNumber': 8,
#     'teamId': 6,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 129,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{F9FBE5BD-6546-4D97-907D-314EBCA8A0A9}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 129,
#     'playerId': 2528210,
#     'reservedForKeeper': False,
#     'roundId': 13,
#     'roundPickNumber': 9,
#     'teamId': 8,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 130,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{05D164B9-F2F4-4FCA-97CF-1A8C0D02200F}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 130,
#     'playerId': 2384,
#     'reservedForKeeper': False,
#     'roundId': 13,
#     'roundPickNumber': 10,
#     'teamId': 9,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 131,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{05D164B9-F2F4-4FCA-97CF-1A8C0D02200F}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 131,
#     'playerId': 4066648,
#     'reservedForKeeper': False,
#     'roundId': 14,
#     'roundPickNumber': 1,
#     'teamId': 9,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 132,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{F9FBE5BD-6546-4D97-907D-314EBCA8A0A9}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 132,
#     'playerId': 3037789,
#     'reservedForKeeper': False,
#     'roundId': 14,
#     'roundPickNumber': 2,
#     'teamId': 8,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 3,
#     'bidAmount': 0,
#     'id': 133,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'nominatingTeamId': 0,
#     'overallPickNumber': 133,
#     'playerId': 3078576,
#     'reservedForKeeper': False,
#     'roundId': 14,
#     'roundPickNumber': 3,
#     'teamId': 6,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 134,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{DD012212-1A35-417E-9883-4B1E44BDF89C}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 134,
#     'playerId': 6579,
#     'reservedForKeeper': False,
#     'roundId': 14,
#     'roundPickNumber': 4,
#     'teamId': 4,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 3,
#     'bidAmount': 0,
#     'id': 135,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'nominatingTeamId': 0,
#     'overallPickNumber': 135,
#     'playerId': 3026,
#     'reservedForKeeper': False,
#     'roundId': 14,
#     'roundPickNumber': 5,
#     'teamId': 7,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 136,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{07B59F4A-A159-414C-B59F-4AA159214C3F}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 136,
#     'playerId': 2581177,
#     'reservedForKeeper': False,
#     'roundId': 14,
#     'roundPickNumber': 6,
#     'teamId': 3,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 137,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{36067DE1-1BAD-475C-867D-E11BADF75C48}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 137,
#     'playerId': 2991070,
#     'reservedForKeeper': False,
#     'roundId': 14,
#     'roundPickNumber': 7,
#     'teamId': 10,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 138,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{335F7A9A-4E5B-4E2C-B35A-CC9AA019E44C}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 138,
#     'playerId': 3024,
#     'reservedForKeeper': False,
#     'roundId': 14,
#     'roundPickNumber': 8,
#     'teamId': 1,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 139,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{073D2BB1-1612-4E20-8066-303B069EAAFF}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 139,
#     'playerId': 2580913,
#     'reservedForKeeper': False,
#     'roundId': 14,
#     'roundPickNumber': 9,
#     'teamId': 5,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 140,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{5AF1DAE9-974E-4B12-864A-A2677B8EB690}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 140,
#     'playerId': 3988,
#     'reservedForKeeper': False,
#     'roundId': 14,
#     'roundPickNumber': 10,
#     'teamId': 2,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 141,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{5AF1DAE9-974E-4B12-864A-A2677B8EB690}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 141,
#     'playerId': 4395725,
#     'reservedForKeeper': False,
#     'roundId': 15,
#     'roundPickNumber': 1,
#     'teamId': 2,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 142,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{073D2BB1-1612-4E20-8066-303B069EAAFF}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 142,
#     'playerId': 4277928,
#     'reservedForKeeper': False,
#     'roundId': 15,
#     'roundPickNumber': 2,
#     'teamId': 5,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 143,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{335F7A9A-4E5B-4E2C-B35A-CC9AA019E44C}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 143,
#     'playerId': 3209,
#     'reservedForKeeper': False,
#     'roundId': 15,
#     'roundPickNumber': 3,
#     'teamId': 1,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 3,
#     'bidAmount': 0,
#     'id': 144,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'nominatingTeamId': 0,
#     'overallPickNumber': 144,
#     'playerId': 4066262,
#     'reservedForKeeper': False,
#     'roundId': 15,
#     'roundPickNumber': 4,
#     'teamId': 10,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 145,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{07B59F4A-A159-414C-B59F-4AA159214C3F}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 145,
#     'playerId': 3964,
#     'reservedForKeeper': False,
#     'roundId': 15,
#     'roundPickNumber': 5,
#     'teamId': 3,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 3,
#     'bidAmount': 0,
#     'id': 146,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'nominatingTeamId': 0,
#     'overallPickNumber': 146,
#     'playerId': 6443,
#     'reservedForKeeper': False,
#     'roundId': 15,
#     'roundPickNumber': 6,
#     'teamId': 7,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 147,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{DD012212-1A35-417E-9883-4B1E44BDF89C}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 147,
#     'playerId': 4395627,
#     'reservedForKeeper': False,
#     'roundId': 15,
#     'roundPickNumber': 7,
#     'teamId': 4,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 3,
#     'bidAmount': 0,
#     'id': 148,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'nominatingTeamId': 0,
#     'overallPickNumber': 148,
#     'playerId': 4269,
#     'reservedForKeeper': False,
#     'roundId': 15,
#     'roundPickNumber': 8,
#     'teamId': 6,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 149,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{F9FBE5BD-6546-4D97-907D-314EBCA8A0A9}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 149,
#     'playerId': 4278104,
#     'reservedForKeeper': False,
#     'roundId': 15,
#     'roundPickNumber': 9,
#     'teamId': 8,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 150,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{05D164B9-F2F4-4FCA-97CF-1A8C0D02200F}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 150,
#     'playerId': 3102530,
#     'reservedForKeeper': False,
#     'roundId': 15,
#     'roundPickNumber': 10,
#     'teamId': 9,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 151,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{05D164B9-F2F4-4FCA-97CF-1A8C0D02200F}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 151,
#     'playerId': 3431,
#     'reservedForKeeper': False,
#     'roundId': 16,
#     'roundPickNumber': 1,
#     'teamId': 9,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 152,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{F9FBE5BD-6546-4D97-907D-314EBCA8A0A9}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 152,
#     'playerId': 4278039,
#     'reservedForKeeper': False,
#     'roundId': 16,
#     'roundPickNumber': 2,
#     'teamId': 8,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 3,
#     'bidAmount': 0,
#     'id': 153,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'nominatingTeamId': 0,
#     'overallPickNumber': 153,
#     'playerId': 3244,
#     'reservedForKeeper': False,
#     'roundId': 16,
#     'roundPickNumber': 3,
#     'teamId': 6,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 154,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{DD012212-1A35-417E-9883-4B1E44BDF89C}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 154,
#     'playerId': 3136196,
#     'reservedForKeeper': False,
#     'roundId': 16,
#     'roundPickNumber': 4,
#     'teamId': 4,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 3,
#     'bidAmount': 0,
#     'id': 155,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'nominatingTeamId': 0,
#     'overallPickNumber': 155,
#     'playerId': 2488653,
#     'reservedForKeeper': False,
#     'roundId': 16,
#     'roundPickNumber': 5,
#     'teamId': 7,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 3,
#     'bidAmount': 0,
#     'id': 156,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'nominatingTeamId': 0,
#     'overallPickNumber': 156,
#     'playerId': 2990962,
#     'reservedForKeeper': False,
#     'roundId': 16,
#     'roundPickNumber': 6,
#     'teamId': 3,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 3,
#     'bidAmount': 0,
#     'id': 157,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'nominatingTeamId': 0,
#     'overallPickNumber': 157,
#     'playerId': 4066650,
#     'reservedForKeeper': False,
#     'roundId': 16,
#     'roundPickNumber': 7,
#     'teamId': 10,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 158,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{335F7A9A-4E5B-4E2C-B35A-CC9AA019E44C}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 158,
#     'playerId': 4395651,
#     'reservedForKeeper': False,
#     'roundId': 16,
#     'roundPickNumber': 8,
#     'teamId': 1,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 3,
#     'bidAmount': 0,
#     'id': 159,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'nominatingTeamId': 0,
#     'overallPickNumber': 159,
#     'playerId': 2991230,
#     'reservedForKeeper': False,
#     'roundId': 16,
#     'roundPickNumber': 9,
#     'teamId': 5,
#     'tradeLocked': False},
#    {'autoDraftTypeId': 0,
#     'bidAmount': 0,
#     'id': 160,
#     'keeper': False,
#     'lineupSlotId': 12,
#     'memberId': '{5AF1DAE9-974E-4B12-864A-A2677B8EB690}',
#     'nominatingTeamId': 0,
#     'overallPickNumber': 160,
#     'playerId': 3147657,
#     'reservedForKeeper': False,
#     'roundId': 16,
#     'roundPickNumber': 10,
#     'teamId': 2,
#     'tradeLocked': False}]},
#  'gameId': 3,
#  'id': 69561285,
#  'scoringPeriodId': 13,
#  'seasonId': 2020,
#  'segmentId': 0,
#  'settings': {'draftSettings': {'auctionBudget': 200,
#    'availableDate': 1571702400000,
#    'date': 1571706000000,
#    'isTradingEnabled': True,
#    'keeperCount': 0,
#    'keeperCountFuture': 0,
#    'keeperOrderType': 'TRADITIONAL',
#    'leagueSubType': 'NONE',
#    'orderType': 'MANUAL',
#    'pickOrder': [2, 5, 1, 10, 3, 7, 4, 6, 8, 9],
#    'timePerSelection': 120,
#    'type': 'SNAKE'}},
#  'status': {'activatedDate': 1570636666717,
#   'createdAsLeagueType': 4,
#   'currentLeagueType': 0,
#   'currentMatchupPeriod': 2,
#   'finalScoringPeriod': 177,
#   'firstScoringPeriod': 1,
#   'isActive': True,
#   'isExpired': False,
#   'isFull': True,
#   'isPlayoffMatchupEdited': False,
#   'isToBeDeleted': False,
#   'isViewable': False,
#   'isWaiverOrderEdited': False,
#   'latestScoringPeriod': 13,
#   'previousSeasons': [2019],
#   'standingsUpdateDate': 1572771488081,
#   'teamsJoined': 10,
#   'transactionScoringPeriod': 13,
#   'waiverLastExecutionDate': 1572771488068,
#   'waiverProcessStatus': {'2019-10-23T08:07:44.270+0000': 2,
#    '2019-10-25T08:00:20.236+0000': 1,
#    '2019-10-31T08:37:15.295+0000': 1,
#    '2019-11-03T08:58:08.068+0000': 1}}}

# %%
teams.json().keys()
# Out:
# dict_keys(['draftDetail', 'gameId', 'id', 'members', 'scoringPeriodId', 'seasonId', 'segmentId', 'status', 'teams'])

# %%
len(teams.json()['teams'])
# Out:
# 10
